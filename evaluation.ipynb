# %%
import os
import faiss
import numpy as np
import openai
from datetime import datetime
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool, ScrapeWebsiteTool, WebsiteSearchTool
from tools.sentiment_analysis_tool import retail_sentiment_analysis
from tools.yf_tech_analysis_tool import yf_tech_analysis
from tools.fundamental_analysis_tool import yf_fundamental_analysis
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from tools.search_tools import SearchTools  # Import the SearchTools class
from tools.news_tool import tradingview_news_tool  # Import the yahoo_news_tool
from crewai_tools import tool
from preprocessing import preprocess_text
from sentence_transformers import SentenceTransformer
import joblib
import requests
from bs4 import BeautifulSoup
from langchain_groq import ChatGroq
load_dotenv()

openai.api_key = os.getenv('OPENAI_API_KEY')

def get_tradingview_news(stock_symbol: str, max_articles: int = 5):
    """Fetch news articles from TradingView."""
    tvnewsdata = []
    url = f"https://news-headlines.tradingview.com/v2/view/headlines/symbol?client=web&lang=en&section=&streaming=true&symbol=NSE%3A{stock_symbol}"
    headers = {
        "sec-ch-ua": '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
        "Referer": "https://in.tradingview.com/",
        "sec-ch-ua-mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
        "sec-ch-ua-platform": '"Windows"'
    }
    
    response = requests.get(url, headers=headers)
    data = response.json()
    story_paths = [item['storyPath'] for item in data['items']]
    
    limit = 0
    for path in story_paths:
        iurl = "https://in.tradingview.com" + path
        response2 = requests.get(iurl, headers=headers)
        soup = BeautifulSoup(response2.content, "html.parser")
        news_content = "\n".join(p.get_text(separator="\n") for p in soup.find_all('p')[:-23])
        tvnewsdata.append(news_content)
        limit += 1
        if limit == max_articles:
            break
            
    return tvnewsdata

@tool
def market_sentiment_analysis(stock_symbol: str, limit: int = 5):
    """
    Perform sentiment analysis on posts from news about a stock symbol.
    
    Args:
        stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE". 
        limit (int): Number of posts to fetch from TradingView.
    
    Returns:
        dict: Sentiment counts for TradingView news.
    """
    print(stock_symbol)
    sentiments_counts = {}
    pipeline, label_encoder = joblib.load(r'E:\Data Science\Capstone\Mindyourstock\text_classification_pipeline.pkl')

    tv_news = get_tradingview_news(stock_symbol, limit)
    for post in tv_news:
        sentiment = pipeline.predict([str(post)])[0]
        sentiment = label_encoder.inverse_transform([sentiment])[0]
        
        if sentiment not in sentiments_counts:
            sentiments_counts[sentiment] = 0
        sentiments_counts[sentiment] += 1

    return sentiments_counts
# Model Selection
def initialize_llm(model_option, api_key):
    if model_option == 'gpt-3.5-turbo-1106':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-3.5-turbo-1106', temperature=0.1)
    elif model_option == 'OpenAI GPT-4o Mini':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-4o-mini', temperature=0.1)
    elif model_option == 'llama3-8b-8192':
        return ChatGroq(groq_api_key=api_key , model='groq/llama3-8b-8192', temperature=0.1)  # Correct provider here 
    else:
        raise ValueError("Invalid model option selected")

# FAISS index initialization
embedding_dim = 768  
index_file = './faiss_index.index'

# Check if FAISS index already exists, else create a new one
if os.path.exists(index_file):
    index = faiss.read_index(index_file)
else:
    index = faiss.IndexFlatL2(embedding_dim)

# Store for metadata (query-response pairs)
query_response_metadata = []

model = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')

def get_embeddings(text):
    """Generate embeddings for the text using HuggingFace's model."""
    embedding = model.encode(text)
    return np.array(embedding)

def store_query_response(query, response):
    """Store the query and response in the FAISS vector DB."""
    # Generate embeddings for the query
    query_embedding = get_embeddings(query)
    
    # Add the embedding to the FAISS index
    index.add(np.array([query_embedding], dtype=np.float32))
    
    # Save the query and response in metadata
    query_response_metadata.append({
        'query': query,
        'response': response
    })
    
    # Persist the FAISS index and metadata
    faiss.write_index(index, index_file)
    with open('query_response_metadata.npy', 'wb') as f:
        np.save(f, query_response_metadata)

def load_metadata():
    """Load stored metadata."""
    if os.path.exists('query_response_metadata.npy'):
        with open('query_response_metadata.npy', 'rb') as f:
            return np.load(f, allow_pickle=True).tolist()
    return []

def find_similar_response(query):
    """Find a similar response from the FAISS index."""
    query_embedding = get_embeddings(query)
    distances, indices = index.search(np.array([query_embedding], dtype=np.float32), k=1)  # Search for the closest response
    
    if distances[0][0] < 1.0:  # A threshold for considering it a match (you can adjust this)
        similar_query = query_response_metadata[indices[0][0]]['query']
        similar_response = query_response_metadata[indices[0][0]]['response']
        return similar_response, similar_query
    return None, None

# Load metadata if it exists
query_response_metadata = load_metadata()


# Function to handle dynamic user queries and responses
def handle_query(user_query, model_option, api_key):
    # First check for a similar response
    stored_response, similar_query = find_similar_response(user_query)

    if stored_response is not None:
        return f"Found a similar response for '{similar_query}': {stored_response}"

    # If no stored response, proceed with agent processing
    llm = initialize_llm(model_option, api_key)

    # Tools Initialization
    retail_sentiment_tool = retail_sentiment_analysis
    serper_tool = SerperDevTool()
    market_sentiment_tool = market_sentiment_analysis
    yf_tech_tool = yf_tech_analysis
    yf_fundamental_tool = yf_fundamental_analysis
    news_tool = tradingview_news_tool

    # Conversation Agent Definition
    converser = Agent(
        role='Financial Data Analyst',
        goal='Dynamically respond to queries using available tools',
        verbose=True,
        memory=True,
        backstory="An expert in financial analysis with deep understanding of various analytic tools, you're adept at providing dynamic and insightful information.",
        tools=[news_tool, yf_fundamental_tool, yf_tech_tool, retail_sentiment_tool, market_sentiment_tool, serper_tool],
        llm=llm
    )
    
    # Agents Definitions
    researcher = Agent(
        role='Senior Stock Market Researcher',
        goal='Gather and analyze comprehensive data about stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a Ph.D. in Financial Economics and 15 years of experience in equity research, you're known for your meticulous data collection and insightful analysis.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, news_tool],
        llm=llm
    )

    technical_analyst = Agent(
        role='Expert Technical Analyst',
        goal='Perform an in-depth technical analysis on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a Chartered Market Technician (CMT) with 15 years of experience, you have a keen eye for chart patterns and market trends.",
        tools=[yf_tech_tool],
        llm=llm
    )
    fundamental_analyst = Agent(
        role='Senior Fundamental Analyst',
        goal='Conduct a comprehensive fundamental analysis of stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a CFA charter and 15 years of experience in value investing, you dissect financial statements and identify key value drivers.",
        tools=[yf_fundamental_tool],
        llm=llm
    )
    reporter = Agent(
        role='Chief Investment Strategist',
        goal='Synthesize all analyses to create a definitive investment report on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a seasoned investment strategist with 20 years of experience, you weave complex financial data into compelling investment narratives.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, yf_fundamental_tool, yf_tech_tool, news_tool],
        llm=llm
    )
    
    # Task for dynamic interaction
    dynamic_task = Task(
        description=(
            "Analyze and respond to the query: {user_query}. Include:\n"
            "tool output in the response"
        ),
        expected_output='Provide a dynamic, interactive response with the data you have available',
        agent=converser
    )
    
    # Task Definitions
    research_task = Task(
        description=(
            "Conduct research on stock symbol in the {user_query}. Your analysis should include:\n"
            "1. Current stock price and historical performance (5 years).\n"
            "2. Key financial metrics (P/E, EPS growth, revenue growth, margins).\n"
            "3. Recent news and press releases (1 month).\n"
            "4. Analyst ratings and price targets (min 3 analysts).\n"
            "5. sentiment analysis (100 posts).\n"
            "6. Major institutional holders and recent changes.\n"
            "7. Competitive landscape and market share.\n"
            "Use reputable financial websites for data."
        ),
        expected_output='A detailed 150-word research report with data sources and brief analysis.',
        agent=researcher
    )
    technical_analysis_task = Task(
        description=(
            "Perform technical analysis on stock_symbol mentioned in {user_query}. Include:\n"
            "1. 50-day and 200-day moving averages (1 year).\n"
            "2. Key support and resistance levels (3 each).\n"
            "3. RSI and MACD indicators.\n"
            "4. Volume analysis (3 months).\n"
            "5. Significant chart patterns (6 months).\n"
            "6. Fibonacci retracement levels.\n"
            "7. Comparison with sector's average.\n"
            "Use the yf_tech_analysis tool for data."
        ),
        expected_output='A 100-word technical analysis report with buy/sell/hold signals and annotated charts.',
        agent=technical_analyst
    )
    fundamental_analysis_task = Task(
        description=(
            "Conduct fundamental analysis of stock_symbol mentioned in {user_query}. Include:\n"
            "1. Review last 3 years of financial statements.\n"
            "2. Key ratios (P/E, P/B, P/S, PEG, Debt-to-Equity, etc.).\n"
            "3. Comparison with main competitors and industry averages.\n"
            "4. Revenue and earnings growth trends.\n"
            "5. Management effectiveness (ROE, capital allocation).\n"
            "6. Competitive advantages and market position.\n"
            "7. Growth catalysts and risks (2-3 years).\n"
            "8. DCF valuation model with assumptions.\n"
            "Use yf_fundamental_analysis tool for data."
        ),
        expected_output='A 100-word fundamental analysis report with buy/hold/sell recommendation and key metrics summary.',
        agent=fundamental_analyst
    )
    report_task = Task(
        description=(
            "Create an investment report on stock_symbol mentioned in {user_query}. Include:\n"
            "1. Executive Summary: Investment recommendation.\n"
            "2. Company Snapshot: Key facts.\n"
            "3. Financial Highlights: Top metrics and peer comparison.\n"
            "4. Technical Analysis: Key findings.\n"
            "5. Fundamental Analysis: Top strengths and concerns.\n"
            "6. Risk and Opportunity: Major risk and growth catalyst.\n"
            "7. Sentiment: Key takeaway from sentiment analysis, including the number of positive, negative and neutral comments and total comments.\n"
            "8. Investment Thesis: Bull and bear cases.\n"
            "9. Price Target: 12-month forecast.\n"
        ),
        expected_output='A 600-word investment report with clear sections, key insights.',
        agent=reporter
    )
    
    # Crew Definition and Kickoff for Dynamic Interaction
    crew = Crew(
        agents=[converser, researcher, technical_analyst, fundamental_analyst, reporter],
        tasks=[dynamic_task, research_task, technical_analysis_task, fundamental_analysis_task, report_task],
        process=Process.sequential,  # Using a sequential process for dynamic interaction
        cache=True
    )

    result = crew.kickoff(inputs={
        'user_query': user_query
    })
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    os.makedirs('./crew_results', exist_ok=True)
    file_path = f"./crew_results/crew_result_{current_time}.pdf"
    result_str = str(result)
    with open(file_path, 'w') as file:
        file.write(result_str)
    
    # Store the result in FAISS
    final_response = result
    
    # Store the query and response in FAISS
    store_query_response(user_query, final_response)
    return final_response

# %%
import os
import faiss
import numpy as np
import openai
from datetime import datetime
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool, ScrapeWebsiteTool, WebsiteSearchTool
from tools.sentiment_analysis_tool import retail_sentiment_analysis
from tools.yf_tech_analysis_tool import yf_tech_analysis
from tools.fundamental_analysis_tool import yf_fundamental_analysis
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from tools.search_tools import SearchTools  # Import the SearchTools class
from tools.news_tool import tradingview_news_tool  # Import the yahoo_news_tool
from crewai_tools import tool
from preprocessing import preprocess_text
from sentence_transformers import SentenceTransformer
import joblib
import requests
from bs4 import BeautifulSoup
from langchain_groq import ChatGroq

# Load environment variables
load_dotenv()

openai.api_key = os.getenv('OPENAI_API_KEY')

# Get TradingView news function
def get_tradingview_news(stock_symbol: str, max_articles: int = 5):
    """Fetch news articles from TradingView."""
    tvnewsdata = []
    url = f"https://news-headlines.tradingview.com/v2/view/headlines/symbol?client=web&lang=en&section=&streaming=true&symbol=NSE%3A{stock_symbol}"
    headers = {
        "sec-ch-ua": '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
        "Referer": "https://in.tradingview.com/",
        "sec-ch-ua-mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
        "sec-ch-ua-platform": '"Windows"'
    }

    response = requests.get(url, headers=headers)
    data = response.json()
    story_paths = [item['storyPath'] for item in data['items']]

    limit = 0
    for path in story_paths:
        iurl = "https://in.tradingview.com" + path
        response2 = requests.get(iurl, headers=headers)
        soup = BeautifulSoup(response2.content, "html.parser")
        news_content = "\n".join(p.get_text(separator="\n") for p in soup.find_all('p')[:-23])
        tvnewsdata.append(news_content)
        limit += 1
        if limit == max_articles:
            break

    return tvnewsdata

# Market sentiment analysis tool using TradingView news
@tool
def market_sentiment_analysis(stock_symbol: str, limit: int = 5):
    """
    Perform sentiment analysis on posts from news about a stock symbol.
    
    Args:
        stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE". 
        limit (int): Number of posts to fetch from TradingView.
    
    Returns:
        dict: Sentiment counts for TradingView news.
    """
    print(stock_symbol)
    sentiments_counts = {}
    pipeline, label_encoder = joblib.load(r'E:\Data Science\Capstone\Mindyourstock\text_classification_pipeline.pkl')

    tv_news = get_tradingview_news(stock_symbol, limit)
    for post in tv_news:
        sentiment = pipeline.predict([str(post)])[0]
        sentiment = label_encoder.inverse_transform([sentiment])[0]

        if sentiment not in sentiments_counts:
            sentiments_counts[sentiment] = 0
        sentiments_counts[sentiment] += 1

    return sentiments_counts

# Initialize different LLM models based on user selection
def initialize_llm(model_option, api_key):
    if model_option == 'gpt-3.5-turbo-1106':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-3.5-turbo-1106', temperature=0.1)
    elif model_option == 'OpenAI GPT-4o Mini':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-4o-mini', temperature=0.1)
    elif model_option == 'llama3-8b-8192':
        return ChatGroq(groq_api_key=api_key, model='groq/llama3-8b-8192', temperature=0.1)
    else:
        raise ValueError("Invalid model option selected")

# FAISS index initialization
embedding_dim = 768
index_file = './faiss_index.index'

# Check if FAISS index already exists, else create a new one
if os.path.exists(index_file):
    index = faiss.read_index(index_file)
else:
    index = faiss.IndexFlatL2(embedding_dim)

# Store for metadata (query-response pairs)
query_response_metadata = []

# Sentence Transformer model for embeddings
model = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')

# Function to get embeddings from text
def get_embeddings(text):
    """Generate embeddings for the text using HuggingFace's model."""
    embedding = model.encode(text)
    return np.array(embedding)

# Function to store query-response pairs in FAISS
def store_query_response(query, response):
    """Store the query and response in the FAISS vector DB."""
    # Generate embeddings for the query
    query_embedding = get_embeddings(query)

    # Add the embedding to the FAISS index
    index.add(np.array([query_embedding], dtype=np.float32))

    # Save the query and response in metadata
    query_response_metadata.append({
        'query': query,
        'response': response
    })

    # Persist the FAISS index and metadata
    faiss.write_index(index, index_file)
    with open('query_response_metadata.npy', 'wb') as f:
        np.save(f, query_response_metadata)

# Function to load stored metadata
def load_metadata():
    """Load stored metadata."""
    if os.path.exists('query_response_metadata.npy'):
        with open('query_response_metadata.npy', 'rb') as f:
            return np.load(f, allow_pickle=True).tolist()
    return []

# Function to find a similar response from FAISS index
def find_similar_response(query):
    """Find a similar response from the FAISS index."""
    query_embedding = get_embeddings(query)
    distances, indices = index.search(np.array([query_embedding], dtype=np.float32), k=1)

    if distances[0][0] < 1.0:
        similar_query = query_response_metadata[indices[0][0]]['query']
        similar_response = query_response_metadata[indices[0][0]]['response']
        return similar_response, similar_query
    return None, None

# Load stored metadata if it exists
query_response_metadata = load_metadata()

# Function to handle dynamic user queries and responses
def handle_query(user_query, model_option, api_key):
    # Self-reflection and check for similar response
    stored_response, similar_query = find_similar_response(user_query)
    if stored_response is not None:
        current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
        os.makedirs('./crew_results', exist_ok=True)
        file_path = f"./crew_results/crew_result_{current_time}.pdf"
        result_str = str(stored_response)
        with open(file_path, 'w') as file:
            file.write(result_str)
        return f"{stored_response}"
    
    

    # Initialize selected LLM
    llm = initialize_llm(model_option, api_key)

    # Initialize tools
    retail_sentiment_tool = retail_sentiment_analysis
    serper_tool = SerperDevTool()
    market_sentiment_tool = market_sentiment_analysis
    yf_tech_tool = yf_tech_analysis
    yf_fundamental_tool = yf_fundamental_analysis
    news_tool = tradingview_news_tool

    # Define Agents with Tree of Thought (ToT) evaluation for better reflection and exploration
    converser = Agent(
        role='Financial Data Analyst',
        goal='Dynamically respond to queries using available tools',
        verbose=True,
        memory=True,
        backstory="An expert in financial analysis with deep understanding of various analytic tools, you're adept at providing dynamic and insightful information.",
        tools=[news_tool, yf_fundamental_tool, yf_tech_tool, retail_sentiment_tool, market_sentiment_tool, serper_tool],
        llm=llm,
        tree_of_thought=True  # Enabling Tree of Thought exploration
    )

    researcher = Agent(
        role='Senior Stock Market Researcher',
        goal='Gather and analyze comprehensive data about stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a Ph.D. in Financial Economics and 15 years of experience in equity research, you're known for your meticulous data collection and insightful analysis.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, news_tool],
        llm=llm,
        tree_of_thought=True  # Multiple hypotheses exploration
    )

    technical_analyst = Agent(
        role='Expert Technical Analyst',
        goal='Perform an in-depth technical analysis on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a Chartered Market Technician (CMT) with 15 years of experience, you have a keen eye for chart patterns and market trends.",
        tools=[yf_tech_tool],
        llm=llm,
        tree_of_thought=True  # Explore different technical indicators and scenarios
    )

    fundamental_analyst = Agent(
        role='Senior Fundamental Analyst',
        goal='Conduct a comprehensive fundamental analysis of stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a CFA charter and 15 years of experience in value investing, you dissect financial statements and identify key value drivers.",
        tools=[yf_fundamental_tool],
        llm=llm,
        tree_of_thought=True  # Explore different valuation methods and financial metrics
    )

    reporter = Agent(
        role='Chief Investment Strategist',
        goal='Synthesize all analyses to create a definitive investment report on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a seasoned investment strategist with 20 years of experience, you weave complex financial data into compelling investment narratives.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, yf_fundamental_tool, yf_tech_tool, news_tool],
        llm=llm,
        tree_of_thought=True
    )

    

        # Task for dynamic interaction
    dynamic_task = Task(
        description=(
            "Analyze and respond to the query: {user_query}. Include:\n"
            "tool output in the response"
        ),
        expected_output='Provide a dynamic, interactive response with the data you have available',
        agent=converser
    )
    
    # Task Definitions
    research_task = Task(
        description=(
            "Conduct research on stock symbol in the {user_query}. Your analysis should include:\n"
            "1. Current stock price and historical performance (5 years).\n"
            "2. Key financial metrics (P/E, EPS growth, revenue growth, margins).\n"
            "3. Recent news and press releases (1 month).\n"
            "4. Analyst ratings and price targets (min 3 analysts).\n"
            "5. market sentiment analysis.\n"
            "6. retail sentiment analysis.\n"
            "7. Major institutional holders and recent changes.\n"
            "8. Competitive landscape and market share.\n"
            "Use reputable financial websites for data."
        ),
        expected_output='A detailed 150-word research report with data sources and brief analysis.',
        agent=researcher
    )
    technical_analysis_task = Task(
        description=(
            "Perform technical analysis on stock_symbol mentioned in {user_query}. Include:\n"
            "1. 50-day and 200-day moving averages (1 year).\n"
            "2. Key support and resistance levels (3 each).\n"
            "3. RSI and MACD indicators.\n"
            "4. Volume analysis (3 months).\n"
            "5. Significant chart patterns (6 months).\n"
            "6. Fibonacci retracement levels.\n"
            "7. Comparison with sector's average.\n"
            "Use the yf_tech_analysis tool for data."
        ),
        expected_output='A 100-word technical analysis report with buy/sell/hold signals and annotated charts.',
        agent=technical_analyst
    )
    fundamental_analysis_task = Task(
        description=(
            "Conduct fundamental analysis of stock_symbol mentioned in {user_query}. Include:\n"
            "1. Review last 3 years of financial statements.\n"
            "2. Key ratios (P/E, P/B, P/S, PEG, Debt-to-Equity, etc.).\n"
            "3. Comparison with main competitors and industry averages.\n"
            "4. Revenue and earnings growth trends.\n"
            "5. Management effectiveness (ROE, capital allocation).\n"
            "6. Competitive advantages and market position.\n"
            "7. Growth catalysts and risks (2-3 years).\n"
            "8. DCF valuation model with assumptions.\n"
            "Use yf_fundamental_analysis tool for data."
        ),
        expected_output='A 100-word fundamental analysis report with buy/hold/sell recommendation and key metrics summary.',
        agent=fundamental_analyst
    )
    report_task = Task(
        description=(
            "Create an investment report on stock_symbol mentioned in {user_query}. Include:\n"
            "1. Executive Summary: Investment recommendation.\n"
            "2. Company Snapshot: Key facts.\n"
            "3. Financial Highlights: Top metrics and peer comparison.\n"
            "4. Technical Analysis: Key findings.\n"
            "5. Fundamental Analysis: Top strengths and concerns.\n"
            "6. Risk and Opportunity: Major risk and growth catalyst.\n"
            "7. Sentiment: Key takeaway from sentiment analysis, including the number of positive, negative and neutral comments and total comments.\n"
            "8. Investment Thesis: Bull and bear cases.\n"
            "9. Price Target: 12-month forecast.\n"
        ),
        expected_output='A 600-word investment report with clear sections, key insights.',
        agent=reporter
    )

    # Create Crew for multi-agent collaboration with recursive feedback and ToT reasoning
    market_analysis_crew = Crew(
        title="Dynamic Stock Market Analysis Crew",
        description="The crew handles stock market analysis using sentiment, technical, and fundamental data.", # Agents perform tasks sequentially with cross-agent evaluations
        agents=[researcher, technical_analyst, fundamental_analyst, converser],
        tasks=[dynamic_task, research_task, technical_analysis_task, fundamental_analysis_task, report_task],
        process=Process.sequential,
        review_phase=True,  # Recursive review phase to evaluate and refine responses
        cache=True
    )

    result = market_analysis_crew.kickoff(inputs={
        'user_query': user_query
    })
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    os.makedirs('./crew_results', exist_ok=True)
    file_path = f"./crew_results/crew_result_{current_time}.pdf"
    result_str = str(result)
    with open(file_path, 'w') as file:
        file.write(result_str)
    
    # Store the result in FAISS
    final_response = result
    
    # Store the query and response in FAISS
    store_query_response(user_query, final_response)
    return final_response
# Example Usage
query = "Can you provide a detailed investment report on BPCL?"
model_option = 'gpt-3.5-turbo-1106'
response = handle_query(query, model_option, os.getenv('OPENAI_API_KEY'))
print(response)
# Out:
# 2024-10-16 05:15:16,818 - 1712 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Financial Data Analyst
# ## Task: Analyze and respond to the query: Can you provide a detailed investment report on BPCL?. Include:
# tool output in the response
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   financials = stock.financials.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:26: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balance_sheet = stock.balance_sheet.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:27: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cash_flow = stock.cashflow.fillna(0).infer_objects(copy=False)
# # Agent: Financial Data Analyst
# ## Thought: I need to gather comprehensive information about BPCL to provide a detailed investment report. I will start by performing fundamental analysis using the yf_fundamental_analysis tool.
# ## Using tool: yf_fundamental_analysis
# ## Tool Input:
# "{\"ticker\": \"BPCL.NS\"}"
# ## Tool Output:
# {'Company Name': 'Bharat Petroleum Corporation Limited', 'Sector': 'Energy', 'Industry': 'Oil & Gas Refining & Marketing', 'Key Ratios': {'P/E Ratio': 7.8002687, 'Forward P/E': 10.191408, 'P/B Ratio': 2.0004704, 'P/S Ratio': 0.33591512, 'PEG Ratio': -0.27, 'Debt to Equity': 72.187, 'Current Ratio': 0, 'Quick Ratio': 0, 'ROE': 0, 'ROA': 0, 'ROIC': 0, 'Gross Margin': 0.14344, 'Operating Margin': 0.03487, 'Net Profit Margin': 0.04231, 'Dividend Yield': 0.0675, 'Payout Ratio': 0.2796}, 'Growth Rates': {'Revenue Growth (YoY)': -0.053053318139345995, 'Net Income Growth (YoY)': 11.603571009596209}, 'Valuation Metrics': {'Market Cap': 1513055322112, 'Enterprise Value': 1930431561728, 'EV/EBITDA': 5.272, 'EV/Revenue': 0.429}, 'Future Estimates': {'Next Year EPS Estimate': 34.22, 'Next Year Revenue Estimate': 0, 'Long-term Growth Rate': 0.03}, 'Simple DCF Valuation': 3494668348597.147, 'Last Updated': '2024-03-31', 'Data Retrieval Date': '2024-10-16', 'Interpretations': {'P/E Ratio': 'Low P/E might indicate undervaluation or low growth expectations', 'Debt to Equity': 'High leverage', 'ROE': 'Potential profitability issues', 'Revenue Growth': 'Slowing growth'}}
# [*********************100%***********************]  1 of 1 completed
# # Agent: Financial Data Analyst
# ## Thought: Observation: The fundamental analysis of BPCL indicates that it operates in the Energy sector, specifically in the Oil & Gas Refining & Marketing industry. The company's key ratios show a low P/E ratio, indicating potential undervaluation or low growth expectations. However, the debt to equity ratio is high, suggesting high leverage. The company's growth rates show a decline in revenue but an increase in net income. The valuation metrics reveal a relatively low EV/EBITDA and EV/Revenue. The future estimates indicate a positive next year EPS estimate and a long-term growth rate of 3%. The simple DCF valuation suggests a significant value.
# Thought: I should also perform a technical analysis using the yf_tech_analysis tool to complement the fundamental analysis.
# ## Using tool: yf_tech_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL.NS\", \"period\": \"1y\"}"
# ## Tool Output:
# {'Current_Price': 348.75, 'Moving_Averages': {'20_MA': 343.0675018310547, '50_MA': 344.4020001220703, '100_MA': 328.57349975585936, '200_MA': 306.6934998321533}, 'Exponential_MAs': {'12_EMA': 343.154198123166, '26_EMA': 343.680190011991, '50_EMA': 340.5204928421731, '200_EMA': 303.1069502404302}, 'MACD': {'MACD': -0.5259918888249899, 'Signal_Line': 0.06979364760410964, 'Histogram': -0.5957855364290996}, 'RSI': 55.561995403622284, 'Bollinger_Bands': {'Upper': 367.48326748139175, 'Middle': 343.0675018310547, 'Lower': 318.65173618071765}, 'Stochastic': {'%K': 42.93193717277487, '%D': 29.598599578697634}, 'ATR': 12.203574044363839, 'OBV': 1102780783.0, 'Fibonacci_Levels': {'0%': 376.0, '23.6%': 326.3751014404297, '38.2%': 295.67495233154295, '50%': 270.8625030517578, '61.8%': 246.05005377197267, '100%': 165.72500610351562}, 'Support_Resistance': {'Support': 322.95001220703125, 'Resistance': 376.0}, 'Potential_Breakout': 'No Breakout', 'Trend': 'Bullish', 'Volume': {'Current': 17182219, 'MA': 12308133.85, 'Trend': 'Above Average'}, 'Statistics': {'Yearly_High': 376.0, 'Yearly_Low': 165.72500610351562, 'Average_Volume': 17539515.08163265, 'Volatility': 0.3611206089762691}, 'Interpretation': {'Trend': 'Bullish', 'RSI': 'Neutral', 'MACD': 'Bearish', 'Stochastic': 'Neutral', 'Bollinger_Bands': 'Neutral', 'Volume': 'High'}}
# BPCL
#
#
# # Agent: Financial Data Analyst
# ## Thought: Observation: The technical analysis of BPCL indicates that the stock is currently in a bullish trend. The moving averages and exponential moving averages show a positive trend, and the RSI suggests a neutral position. The MACD is bearish, and the stochastic indicator is neutral. The Bollinger Bands and volume are also in neutral positions. The stock is currently not showing a potential breakout.
# Thought: To gain insights into market sentiment, I will use the market_sentiment_analysis tool to analyze news sentiment about BPCL.
# ## Using tool: market_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"limit\": 5}"
# ## Tool Output:
# {'hold': 4, 'sell': 1}
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: tradingview_news_tool(*args: Any, **kwargs: Any) -> Any
# Tool Description: tradingview_news_tool(stock_symbol: 'string', max_articles: 'integer') -      Get the news articles from TradingView about a stock symbol.      Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".         max_articles (int): The maximum number of articles to fetch.      Returns:         list: A list containing the news articles from TradingView.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'max_articles': {'title': 'Max Articles', 'type': 'integer'}}
# Tool Name: yf_fundamental_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_fundamental_analysis(ticker: 'string') -      Perform a comprehensive fundamental analysis on the given stock symbol.          Args:         ticker (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".          Returns:         dict: A dictionary with the detailed fundamental analysis results.
# Tool Arguments: {'ticker': {'title': 'Ticker', 'type': 'string'}}
# Tool Name: yf_tech_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_tech_analysis(stock_symbol: 'string', period: 'string') -      Perform a comprehensive technical analysis on the given stock symbol.          Args:         stock_symbol (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".         period (str): The time period for analysis. Default is "1y" (1 year).          Returns:         dict: A dictionary with the detailed technical analysis results.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'period': {'title': 'Period', 'type': 'string'}}
# Tool Name: retail_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: retail_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from TradingView Minds about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for in tradingview ex: "HDFCBANK","LTIM","RELIANCE".         limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView posts.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: market_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: market_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from news about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".          limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView news.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: Search the internet(**kwargs: Any) -> Any
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'title': 'Search Query', 'type': 'string'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [tradingview_news_tool, yf_fundamental_analysis, yf_tech_analysis, retail_sentiment_analysis, market_sentiment_analysis, Search the internet], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: Financial Data Analyst
# ## Thought: Thought: I should gather sentiment analysis from retail investors using the retail_sentiment_analysis tool to provide a comprehensive investment report on BPCL.
# ## Using tool: retail_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"limit\": 5}"
# ## Tool Output:
# {'neutral': 4, 'negative': 0, 'positive': 1}
#
#
# # Agent: Financial Data Analyst
# ## Final Answer:
# Based on the comprehensive analysis of BPCL, the fundamental analysis indicates that the company operates in the Energy sector, specifically in the Oil & Gas Refining & Marketing industry. The key ratios suggest potential undervaluation or low growth expectations due to the low P/E ratio, but there is a concern regarding high leverage indicated by the high debt to equity ratio. The growth rates show a decline in revenue but an increase in net income. The valuation metrics reveal relatively low EV/EBITDA and EV/Revenue. The future estimates indicate a positive next year EPS estimate and a long-term growth rate of 3%. The simple DCF valuation suggests a significant value.
#
# The technical analysis indicates that the stock is currently in a bullish trend, with positive moving averages and exponential moving averages. The RSI suggests a neutral position, while the MACD is bearish and the stochastic indicator is neutral. The Bollinger Bands and volume are also in neutral positions, and the stock is currently not showing a potential breakout.
#
# Market sentiment analysis from news sources indicates a neutral sentiment, with 4 "hold" and 1 "sell" sentiment. Retail sentiment analysis shows a mostly neutral sentiment, with 4 "neutral" and 1 "positive" sentiment.
#
# In conclusion, the comprehensive analysis suggests that BPCL may be undervalued with potential for growth, but the high leverage and declining revenue growth are areas of concern. The bullish trend in the technical analysis and the mostly neutral sentiment from both news and retail sources provide additional insights for consideration in making an investment decision.
#
#
# # Agent: Senior Stock Market Researcher
# ## Task: Conduct research on stock symbol in the Can you provide a detailed investment report on BPCL?. Your analysis should include:
# 1. Current stock price and historical performance (5 years).
# 2. Key financial metrics (P/E, EPS growth, revenue growth, margins).
# 3. Recent news and press releases (1 month).
# 4. Analyst ratings and price targets (min 3 analysts).
# 5. sentiment analysis (100 posts).
# 6. Major institutional holders and recent changes.
# 7. Competitive landscape and market share.
# Use reputable financial websites for data.
#
#
# # Agent: Senior Stock Market Researcher
# ## Thought: I need to gather comprehensive data on BPCL to provide a detailed investment report. This will involve collecting information on the current stock price, historical performance, key financial metrics, recent news and press releases, analyst ratings and price targets, sentiment analysis, major institutional holders, recent changes, competitive landscape, and market share.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"BPCL stock price and historical performance\"}"
# ## Tool Output:
#
# Search results: Title: Bharat Petroleum Historical Price Data (BPCL) - Investing.com
# Link: https://www.investing.com/equities/bharat-petroleum-historical-data
# Snippet: BPCL Historical Data ; Highest: 376.00 ; Change %:. -2.40 ; Average: 342.70 ; Difference: 53.05 ; Lowest: 322.95.
# ---
# Title: Bharat Petroleum Corporation Limited (BPCL.NS) - Yahoo Finance
# Link: https://finance.yahoo.com/quote/BPCL.NS/history/
# Snippet: Discover historical prices for BPCL.NS stock on Yahoo Finance. View daily, weekly or monthly format back to when Bharat Petroleum Corporation Limited stock ...
# ---
# Title: Bharat Petroleum Corporation Limited (BPCL.BO) - Yahoo Finance
# Link: https://finance.yahoo.com/quote/BPCL.BO/history/
# Snippet: Bharat Petroleum Corporation Limited (BPCL.BO) ; Jun 25, 2024, 305.00, 306.50 ; Jun 24, 2024, 309.25, 309.25 ; Jun 21, 2024, 2:1 Stock Splits ; Jun 21, 2024, 317.00 ...
# ---
# Title: Bharat Petroleum | BPCL - Stock Price | Live Quote | Historical Chart
# Link: https://tradingeconomics.com/bpcl:in
# Snippet: Bharat Petroleum traded at 340.75 this Monday October 14th, increasing 3.10 or 0.92 percent since the previous trading session. Looking back, over the last ...
# ---
# Title: Bharat Petroleum Corporation Historical Data, BPCL, Live NSE/BSE ...
# Link: https://www.equitypandit.com/historical-data/BPCL
# Snippet: BPCL Historical Data. Equitypandit Financial Services Pvt. Ltd. Date, Price, Open, High, Low, Volume, Change(%). 11 Oct 2024, 337.65, 335.45, 339.40, 334.00 ...
# ---
# Title: Bharat Petroleum Corporation Ltd. - Share/Stock Price - Moneycontrol
# Link: https://www.moneycontrol.com/india/stockpricequote/refineries/bharatpetroleumcorporation/BPC
# Snippet: Get all the information on BPCL with historic price charts for NSE / BSE ... Advance Chart. BPCL. 337.65. 2.20(0.66%). Top 5 Trending Stocks. NSE ...
# ---
# Title: Bharat Petroleum Corporation Ltd. Share Price - Value Research
# Link: https://www.valueresearchonline.com/stocks/41360/bharat-petroleum-corporation-ltd/
# Snippet: What is the current share price of Bharat Petroleum Corporation Ltd? The share price of Bharat Petroleum Corporation Ltd is ₹340.75 (NSE) and ₹340.20 (BSE) ...
# ---
# Title: BPCL - Bharat Petroleum Corporation Share Price
# Link: https://economictimes.indiatimes.com/bharat-petroleum-corporation-ltd/stocks/companyid-11941.cms
# Snippet: BPCL Share Price Returns ; 1 Day, 2.35% ; 1 Month, 1.88% ; 3 Months, 13.32% ; 1 Year, 100.6% ; 3 Years, 51.86%.
# ---
# Title: BPCL Share Price Live Updates: BPCL's stock price rises significantly
# Link: https://m.economictimes.com/markets/stocks/stock-liveblog/bpcl-live-updates-today-15-oct-2024/liveblog/114233256.cms
# Snippet: BPCL is currently trading at Rs 346.30, reflecting a 1.63% increase today, with impressive 3-year returns of 51.34%. 12:47:59 PM IST, 15 Oct ...
# ---
# Title: Bharat Petroleum Share Price Today - BPCL Live Updates NSE/BSE
# Link: https://dhan.co/stocks/bharat-petroleum-ltd-share-price/
# Snippet: Bharat Petroleum Stock Price Today - Get BPCL Share Price History, Real ... Historical Performance. 3 M High. 376.00. 3 M Low. 296.10. 1 Yr High. 477.15. 1 Yr ...
# ---
#
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"BPCL key financial metrics P/E, EPS growth, revenue growth, margins\"}"
# ## Tool Output:
#
# Search results: Title: Bharat Petroleum Corporation Key Financial Ratios ... - Moneycontrol
# Link: https://www.moneycontrol.com/financials/bharatpetroleumcorporation/ratiosVI/BPC
# Snippet: Financials ; Profitability Ratios ; PBDIT Margin (%), 10.39, 2.77 ; PBIT Margin (%), 8.88, 1.43 ; PBT Margin (%), 7.93, 0.46 ; Net Profit Margin (%), 5.95, 0.39 ...
# ---
# Title: Bharat Petroleum (BPCL) Financial Ratios - Investing.com
# Link: https://www.investing.com/equities/bharat-petroleum-ratios
# Snippet: This BPCL page provides a table containing critical financial ratios such as P/E Ratio, EPS, ROI, and others.
# ---
# Title: Bharat Petroleum Corporation Limited (BPCL.BO) - Yahoo Finance
# Link: https://finance.yahoo.com/quote/BPCL.BO/key-statistics/
# Snippet: Revenue (ttm), 4.5T. Revenue Per Share (ttm), 1,056.35. Quarterly Revenue Growth (yoy), 0.10%. Gross Profit (ttm), --. EBITDA, 366.18B. Net Income Avi to Common ...
# ---
# Title: BPCL 2023-24 Annual Report Analysis - Equitymaster
# Link: https://www.equitymaster.com/research-it/annual-results-analysis/BPCL/BPCL-2023-24-Annual-Report-Analysis/10971
# Snippet: The company's operating profit increased by 275.4% YoY during the fiscal. Operating profit margins witnessed a fall and down at 11.5% in FY24 as against 2.9% in ...
# ---
# Title: BPCL.IN | Bharat Petroleum Corp. Ltd. Financial Statements - WSJ
# Link: https://www.wsj.com/market-data/quotes/IN/XNSE/BPCL/financials
# Snippet: Ratios & Margins Bharat Petroleum Corp. Ltd. All values updated annually at ... Sales or Revenue Growth, -3.08%. EBITDA, +56.30 B. 2023, 5-year trend. Net ...
# ---
# Title: Revenue - Bharat Petroleum Corporation Ltd (NSE:BPCL)
# Link: https://www.alphaspread.com/security/nse/bpcl/financials/income-statement/revenue
# Snippet: The average annual Revenue growth rates for Bharat Petroleum Corporation Ltd have been 14% over the past three years , 8% over the past five years .
# ---
# Title: Bharat Petroleum Corporation Ltd. Share Price - Value Research
# Link: https://www.valueresearchonline.com/stocks/41360/bharat-petroleum-corporation-ltd/
# Snippet: Fundamentals · Market cap. ₹1,47,595 Cr · P/E Ratio. 7.75 · P/B Ratio. 1.84 · Industry P/E 14.4 · Debt to Equity. 0.36 · ROE. 26.86 % · ROCE. -- · Div. Yield. 9.26 % ...
# ---
# Title: Bharat Petroleum Corporation Limited - BPCL.NS - Yahoo Finance
# Link: https://nz.finance.yahoo.com/quote/BPCL.NS/key-statistics/
# Snippet: Get all the key statistics for Bharat Petroleum Corporation Limited (BPCL.NS), including valuation measures, fiscal year financial statistics, ...
# ---
# Title: Bharat Petroleum (NSE:BPCL) PE Ratio (TTM) - GuruFocus
# Link: https://www.gurufocus.com/term/pettm/NSE:BPCL
# Snippet: During the past 12 months, Bharat Petroleum's average EPS without NRI Growth Rate was -7.90% per year. During the past 3 years, the average EPS without NRI ...
# ---
# Title: Bharat Petroleum Corporation Ltd. - BPCL - Finology Ticker
# Link: https://ticker.finology.in/company/BPCL
# Snippet: Strengths ; The company has shown a good revenue growth of 24.43% for the Past 3 years. ; The company has significantly decreased its debt by 17,229.90 Cr.
# ---
#
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: tradingview_news_tool
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"max_articles\": 10}"
# ## Tool Output:
# ['Indian indices settled lower on Tuesday, dragged mainly by auto, metal, and pharmaceutical stocks. \nSeptember data showing inflation rose to a nine-month high also dampened investor sentiment as this could push domestic rate cuts to 2025 instead of December this year. \nAt close, the BSE Sensex fell 152.93, or 0.2%, to 81,820.12, while the NSE Nifty 50 slipped 70.60 points, or 0.3%, to 25,057.35. \nHDFC Life Insurance \nHDFCLIFE\n topped the losers on Tuesday, with shares slumping 4%, followed by Bajaj Auto (NSE:BAJAJ/AUTO, \nBAJAJ_AUTO\n) and Wipro \nWIPRO\n. \nConversely, Bharat Petroleum \nBPCL\n, ICICI Bank \nICICIBANK\n and Britannia Industries \nBRITANNIA\n were the top gainers. \nIn corporate news, APL Apollo Tubes \nAPLAPOLLO\n has raised 1 billion Indian rupees from the issue of commercial papers. \nMeanwhile, BEML \nBEML\n has bagged a contract worth 8.67 billion Indian rupees from Integral Coach Factory (ICF), Chennai.\n', '** Shares of Bharat Petroleum Corp Ltd \nBPCL\n, Indian Oil Corp Ltd \nIOC\n and Hindustan Petroleum Corp Ltd \nHINDPETRO\n up 2.6%, 2% and 4.5%, respectively \n** Global oil prices slid after a media report said Israel is willing not to strike Iranian oil targets, easing fears of a supply disruption \n** Lower oil prices benefit oil refiners such as BPCL, IOC and HPCL, which count crude as a major raw material\n** BPCL stock top pct gainer in blue-chip Nifty 50 \nNIFTY\n index\n** All three stocks rated "hold" on avg - LSEG data\n** HPCL leads YTD gains, up 137.4%; BPCL up 96% and top YTD gainer on NSEI, while IOC up 82%\n', 'PL Capital has come out with its second quarter (July-September’ 24) earnings estimates for the Oil & Gas sector. The brokerage house expects BPCL to report net profit at Rs. 3,260 crore down 61.6% year-on-year (up 8.2% quarter-on-quarter).\nNet Sales are expected to decrease by 4.2 percent Y-o-Y (down 12.8 percent Q-o-Q) to Rs. 98,610 crore, according to PL Capital.\nEarnings before interest, tax, depreciation and amortisation (EBITDA) are likely to fall by 52.2 percent Y-o-Y (up 9.2 percent Q-o-Q) to Rs. 6,170 crore.\nDisclaimer: The views and investment tips expressed by investment experts on moneycontrol.com are their own, and not that of the website or its management. Moneycontrol.com advises users to check with certified experts before taking any investment decisions.PL Capital_Oil & Gas\n', '', 'Sensex and Nifty closed in the red for the fifth session on October 4 amid worries about escalating conflict in the Middle East. Banking, FMCG, and auto stocks bore the brunt of the sell-off, while IT stocks offered a brief glimmer of hope amidst the market turmoil.\nAt close, the Sensex was down 808 points or 1 percent at 81,688 and the Nifty was down 200 points or 0.8 percent at 25,049. About 1,521 shares advanced, 2,266 shares declined, and 101 shares remained unchanged.\xa0Sensex and Nifty logged their biggest weekly drop since June 2022. This week, Nifty fell 4.3 percent and Sensex dropped 4.5 percent.\nConcerns over the escalating conflict in the Middle East have raised fears of potential disruptions to crude supplies from the top oil-producing region, pushing prices higher—a situation that impacts net importers like India.\xa0Brent Crude futures have surged over 9 percent so far in October to over $78 per barrel.\nMeanwhile, FIIs are diverting funds to China following its recent stimulus measures.\xa0The last three days have witnessed FIIs selling Rs 30,614 crores in the cash market. In just a week, China-dedicated funds have seen inflows worth over $13 billion while India-dedicated funds received just $107 million, Cameron Brandt, Director of Research at EPFR Global said in an interaction with CNBC-TV18.\nFollow our live blog for all the market action\n"The last three days have witnessed huge FII selling of Rs 30,614 crores in the cash market. FIIs are moving money from expensive India to cheap Hong Kong on expectations that the monetary and fiscal stimulus being i ...
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: market_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: market_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from news about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".          limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView news.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: retail_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: retail_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from TradingView Minds about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for in tradingview ex: "HDFCBANK","LTIM","RELIANCE".         limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView posts.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: Search the internet(**kwargs: Any) -> Any
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'title': 'Search Query', 'type': 'string'}}
# Tool Name: tradingview_news_tool(*args: Any, **kwargs: Any) -> Any
# Tool Description: tradingview_news_tool(stock_symbol: 'string', max_articles: 'integer') -      Get the news articles from TradingView about a stock symbol.      Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".         max_articles (int): The maximum number of articles to fetch.      Returns:         list: A list containing the news articles from TradingView.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'max_articles': {'title': 'Max Articles', 'type': 'integer'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [market_sentiment_analysis, retail_sentiment_analysis, Search the internet, tradingview_news_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"BPCL analyst ratings and price targets\"}"
# ## Tool Output:
#
# Search results: Title: Consensus Bharat Petroleum Corporation Limited - MarketScreener
# Link: https://www.marketscreener.com/quote/stock/BHARAT-PETROLEUM-CORPORAT-9743071/consensus/
# Snippet: Analysts' recommendations: Bharat Petroleum Corporation Limited · Jefferies Adjusts Bharat Petroleum's Price Target to INR385 From INR365, Keeps at Buy · Time ...
# ---
# Title: Bharat Petroleum Corporation Ltd. Brokerage/Research Reports ...
# Link: https://trendlyne.com/research-reports/stock/215/BPCL/bharat-petroleum-corporation-ltd/
# Snippet: Bharat Petroleum Corporation Ltd. has an average target of 318. The consensus estimate represents a downside of -5.82% from the last price of 337.65.
# ---
# Title: Bharat Petroleum Corporation Limited (BPCL.NS) - Yahoo Finance
# Link: https://finance.yahoo.com/quote/BPCL.NS/analysis/
# Snippet: ... Q3'23 Q4'23 Q1'24 Q2'24. Analyst Recommendations. Strong Buy. Buy. Hold. Underperform. Sell. Analyst Price Targets. 230.00 Low. 325.19 Average. 338.20 Current.
# ---
# Title: Bharat Petroleum (BPCL) Stock Forecast & Price Target
# Link: https://www.investing.com/equities/bharat-petroleum-consensus-estimates
# Snippet: BPCL Analyst Price Target ; High · 460.00 ; Average · 340.20 ; Low · 250.00.
# ---
# Title: BPCL Analyst Estimates: Price Targets, Revenue, Net Income, and ...
# Link: https://www.alphaspread.com/security/nse/BPCL/analyst-estimates
# Snippet: According to Wall Street analysts, the average 1-year price target for BPCL is 323.93 INR with a low forecast of 227.25 INR and a high forecast of 477.75 INR.
# ---
# Title: Bharat Petroleum Corporation Ltd. - Share/Stock Price - Moneycontrol
# Link: https://www.moneycontrol.com/india/stockpricequote/refineries/bharatpetroleumcorporation/BPC
# Snippet: Strengths (6) Strong Momentum: Price above short, medium and long term moving averages ; Weaknesses (2) Declining Net Cash Flow : Companies not able to generate ...
# ---
# Title: Bharat Petroleum Corporation Ltd. Share Price Target, Consensus ...
# Link: https://trendlyne.com/equity/consensus-estimates/215/BPCL/bharat-petroleum-corporation-ltd/
# Snippet: Bharat Petroleum Corporation Ltd. has a share price target of Rs 338, revenue growth forecast of 3.4%, and profit growth estimate of -48.6% for FY25, ...
# ---
# Title: Bharat Petroleum Corporation Limited (BPCL.NS) Analyst Ratings ...
# Link: https://ca.finance.yahoo.com/quote/BPCL.NS/analysis/
# Snippet: See Bharat Petroleum Corporation Limited (BPCL.NS) stock analyst ... Analyst Price Targets (30). Current 315.95. Average 321.38. Low 225.00. High 470.00.
# ---
# Title: bharat petroleum corporation limited (bpcl) - MSN
# Link: https://www.msn.com/en-us/money/stockdetails/bpcl-in-stock/fi-ahh9h7?ocid=ob-fb-esxl-714
# Snippet: Based on 31 analysts. 12-month price targetINR 338.20. Based on 30 analysts. Price volatilityHigh. BPCL is rated Hold by analysts. Analyst Price Targets. 2024 ...
# ---
#
# BPCL
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: market_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"limit\": 100}"
# ## Tool Output:
# {'hold': 96, 'sell': 3, 'buy': 1}
#
#
# # Agent: Senior Stock Market Researcher
# ## Final Answer:
# BPCL's current stock price is around INR 337.65, with a 1-year price target ranging from INR 227.25 to INR 477.75, as per analyst estimates. The historical performance shows a 3-year return of 51.86% and a 1-year return of 100.6%. Key financial metrics indicate a P/E ratio of 7.75, revenue growth forecast of 3.4%, and profit growth estimate of -48.6% for FY25. Recent news highlights geopolitical tensions impacting the market, with a focus on the Middle East conflict and its potential impact on crude oil supplies. Market sentiment analysis reveals a predominantly "hold" sentiment, with 96 "hold", 3 "sell", and 1 "buy" sentiment counts. This comprehensive analysis suggests potential undervaluation with growth opportunities, but caution is warranted due to geopolitical risks and declining profit growth.
#
#
# # Agent: Expert Technical Analyst
# ## Task: Perform technical analysis on stock_symbol mentioned in Can you provide a detailed investment report on BPCL?. Include:
# 1. 50-day and 200-day moving averages (1 year).
# 2. Key support and resistance levels (3 each).
# 3. RSI and MACD indicators.
# 4. Volume analysis (3 months).
# 5. Significant chart patterns (6 months).
# 6. Fibonacci retracement levels.
# 7. Comparison with sector's average.
# Use the yf_tech_analysis tool for data.
#
#
# # Agent: Expert Technical Analyst
# ## Thought: I need to gather comprehensive technical analysis on BPCL to provide a detailed investment report.
# ## Using tool: yf_tech_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL.NS\", \"period\": \"1y\"}"
# ## Tool Output:
# {'Current_Price': 348.75, 'Moving_Averages': {'20_MA': 343.0675018310547, '50_MA': 344.4020001220703, '100_MA': 328.57349975585936, '200_MA': 306.6934998321533}, 'Exponential_MAs': {'12_EMA': 343.154198123166, '26_EMA': 343.680190011991, '50_EMA': 340.5204928421731, '200_EMA': 303.1069502404302}, 'MACD': {'MACD': -0.5259918888249899, 'Signal_Line': 0.06979364760410964, 'Histogram': -0.5957855364290996}, 'RSI': 55.561995403622284, 'Bollinger_Bands': {'Upper': 367.48326748139175, 'Middle': 343.0675018310547, 'Lower': 318.65173618071765}, 'Stochastic': {'%K': 42.93193717277487, '%D': 29.598599578697634}, 'ATR': 12.203574044363839, 'OBV': 1102780783.0, 'Fibonacci_Levels': {'0%': 376.0, '23.6%': 326.3751014404297, '38.2%': 295.67495233154295, '50%': 270.8625030517578, '61.8%': 246.05005377197267, '100%': 165.72500610351562}, 'Support_Resistance': {'Support': 322.95001220703125, 'Resistance': 376.0}, 'Potential_Breakout': 'No Breakout', 'Trend': 'Bullish', 'Volume': {'Current': 17182219, 'MA': 12308133.85, 'Trend': 'Above Average'}, 'Statistics': {'Yearly_High': 376.0, 'Yearly_Low': 165.72500610351562, 'Average_Volume': 17539515.08163265, 'Volatility': 0.3611206089762691}, 'Interpretation': {'Trend': 'Bullish', 'RSI': 'Neutral', 'MACD': 'Bearish', 'Stochastic': 'Neutral', 'Bollinger_Bands': 'Neutral', 'Volume': 'High'}}
#
#
# # Agent: Expert Technical Analyst
# ## Final Answer:
# BPCL's technical analysis suggests a hold position, with a close watch on the MACD and RSI for potential reversal signals. The stock is currently in a bullish trend, trading above key moving averages and showing strong volume interest. However, caution is advised due to the bearish MACD and neutral RSI.
#
#
# # Agent: Senior Fundamental Analyst
# ## Task: Conduct fundamental analysis of stock_symbol mentioned in Can you provide a detailed investment report on BPCL?. Include:
# 1. Review last 3 years of financial statements.
# 2. Key ratios (P/E, P/B, P/S, PEG, Debt-to-Equity, etc.).
# 3. Comparison with main competitors and industry averages.
# 4. Revenue and earnings growth trends.
# 5. Management effectiveness (ROE, capital allocation).
# 6. Competitive advantages and market position.
# 7. Growth catalysts and risks (2-3 years).
# 8. DCF valuation model with assumptions.
# Use yf_fundamental_analysis tool for data.
#
#
# # Agent: Senior Fundamental Analyst
# ## Thought: I need to use the yf_fundamental_analysis tool to gather the necessary information for conducting a comprehensive fundamental analysis of BPCL.
# ## Using tool: yf_fundamental_analysis
# ## Tool Input:
# "{\"ticker\": \"BPCL.NS\"}"
# ## Tool Output:
# {'Company Name': 'Bharat Petroleum Corporation Limited', 'Sector': 'Energy', 'Industry': 'Oil & Gas Refining & Marketing', 'Key Ratios': {'P/E Ratio': 7.8002687, 'Forward P/E': 10.191408, 'P/B Ratio': 2.0004704, 'P/S Ratio': 0.33591512, 'PEG Ratio': -0.27, 'Debt to Equity': 72.187, 'Current Ratio': 0, 'Quick Ratio': 0, 'ROE': 0, 'ROA': 0, 'ROIC': 0, 'Gross Margin': 0.14344, 'Operating Margin': 0.03487, 'Net Profit Margin': 0.04231, 'Dividend Yield': 0.0675, 'Payout Ratio': 0.2796}, 'Growth Rates': {'Revenue Growth (YoY)': -0.053053318139345995, 'Net Income Growth (YoY)': 11.603571009596209}, 'Valuation Metrics': {'Market Cap': 1513055322112, 'Enterprise Value': 1930431561728, 'EV/EBITDA': 5.272, 'EV/Revenue': 0.429}, 'Future Estimates': {'Next Year EPS Estimate': 34.22, 'Next Year Revenue Estimate': 0, 'Long-term Growth Rate': 0.03}, 'Simple DCF Valuation': 3494668348597.147, 'Last Updated': '2024-03-31', 'Data Retrieval Date': '2024-10-16', 'Interpretations': {'P/E Ratio': 'Low P/E might indicate undervaluation or low growth expectations', 'Debt to Equity': 'High leverage', 'ROE': 'Potential profitability issues', 'Revenue Growth': 'Slowing growth'}}
#
#
# # Agent: Senior Fundamental Analyst
# ## Final Answer:
# Based on the fundamental analysis, a cautious hold recommendation is advised for BPCL due to potential undervaluation, high leverage, and concerns about profitability and revenue growth. Key metrics indicate a low P/E ratio, high debt-to-equity ratio, and negative revenue growth, suggesting a need for careful monitoring of the company's performance.
#
#
# # Agent: Chief Investment Strategist
# ## Task: Create an investment report on stock_symbol mentioned in Can you provide a detailed investment report on BPCL?. Include:
# 1. Executive Summary: Investment recommendation.
# 2. Company Snapshot: Key facts.
# 3. Financial Highlights: Top metrics and peer comparison.
# 4. Technical Analysis: Key findings.
# 5. Fundamental Analysis: Top strengths and concerns.
# 6. Risk and Opportunity: Major risk and growth catalyst.
# 7. Sentiment: Key takeaway from sentiment analysis, including the number of positive, negative and neutral comments and total comments.
# 8. Investment Thesis: Bull and bear cases.
# 9. Price Target: 12-month forecast.
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   financials = stock.financials.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:26: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balance_sheet = stock.balance_sheet.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:27: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cash_flow = stock.cashflow.fillna(0).infer_objects(copy=False)
# # Agent: Chief Investment Strategist
# ## Thought: I need to gather comprehensive data and insights to create a detailed investment report on BPCL. This will involve analyzing the company's financials, technical indicators, market sentiment, and potential risks and opportunities.
# ## Using tool: yf_fundamental_analysis
# ## Tool Input:
# "{\"ticker\": \"BPCL.NS\"}"
# ## Tool Output:
# {'Company Name': 'Bharat Petroleum Corporation Limited', 'Sector': 'Energy', 'Industry': 'Oil & Gas Refining & Marketing', 'Key Ratios': {'P/E Ratio': 7.8002687, 'Forward P/E': 10.191408, 'P/B Ratio': 2.0004704, 'P/S Ratio': 0.33591512, 'PEG Ratio': -0.27, 'Debt to Equity': 72.187, 'Current Ratio': 0, 'Quick Ratio': 0, 'ROE': 0, 'ROA': 0, 'ROIC': 0, 'Gross Margin': 0.14344, 'Operating Margin': 0.03487, 'Net Profit Margin': 0.04231, 'Dividend Yield': 0.0675, 'Payout Ratio': 0.2796}, 'Growth Rates': {'Revenue Growth (YoY)': -0.053053318139345995, 'Net Income Growth (YoY)': 11.603571009596209}, 'Valuation Metrics': {'Market Cap': 1513055322112, 'Enterprise Value': 1930431561728, 'EV/EBITDA': 5.272, 'EV/Revenue': 0.429}, 'Future Estimates': {'Next Year EPS Estimate': 34.22, 'Next Year Revenue Estimate': 0, 'Long-term Growth Rate': 0.03}, 'Simple DCF Valuation': 3494668348597.147, 'Last Updated': '2024-03-31', 'Data Retrieval Date': '2024-10-16', 'Interpretations': {'P/E Ratio': 'Low P/E might indicate undervaluation or low growth expectations', 'Debt to Equity': 'High leverage', 'ROE': 'Potential profitability issues', 'Revenue Growth': 'Slowing growth'}}
# [*********************100%***********************]  1 of 1 completed
# # Agent: Chief Investment Strategist
# ## Thought: Observation: The fundamental analysis of BPCL reveals several key insights. The company, Bharat Petroleum Corporation Limited, operates in the Energy sector, specifically in the Oil & Gas Refining & Marketing industry. The analysis provides essential financial ratios, growth rates, valuation metrics, future estimates, and interpretations.
# ## Using tool: yf_tech_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL.NS\", \"period\": \"1y\"}"
# ## Tool Output:
# {'Current_Price': 348.75, 'Moving_Averages': {'20_MA': 343.0675018310547, '50_MA': 344.4020001220703, '100_MA': 328.57349975585936, '200_MA': 306.6934998321533}, 'Exponential_MAs': {'12_EMA': 343.154198123166, '26_EMA': 343.680190011991, '50_EMA': 340.5204928421731, '200_EMA': 303.1069502404302}, 'MACD': {'MACD': -0.5259918888249899, 'Signal_Line': 0.06979364760410964, 'Histogram': -0.5957855364290996}, 'RSI': 55.561995403622284, 'Bollinger_Bands': {'Upper': 367.48326748139175, 'Middle': 343.0675018310547, 'Lower': 318.65173618071765}, 'Stochastic': {'%K': 42.93193717277487, '%D': 29.598599578697634}, 'ATR': 12.203574044363839, 'OBV': 1102780783.0, 'Fibonacci_Levels': {'0%': 376.0, '23.6%': 326.3751014404297, '38.2%': 295.67495233154295, '50%': 270.8625030517578, '61.8%': 246.05005377197267, '100%': 165.72500610351562}, 'Support_Resistance': {'Support': 322.95001220703125, 'Resistance': 376.0}, 'Potential_Breakout': 'No Breakout', 'Trend': 'Bullish', 'Volume': {'Current': 17182219, 'MA': 12308133.85, 'Trend': 'Above Average'}, 'Statistics': {'Yearly_High': 376.0, 'Yearly_Low': 165.72500610351562, 'Average_Volume': 17539515.08163265, 'Volatility': 0.3611206089762691}, 'Interpretation': {'Trend': 'Bullish', 'RSI': 'Neutral', 'MACD': 'Bearish', 'Stochastic': 'Neutral', 'Bollinger_Bands': 'Neutral', 'Volume': 'High'}}
# BPCL
#
#
# # Agent: Chief Investment Strategist
# ## Thought: Observation: The technical analysis of BPCL over the past year indicates a bullish trend, with the current price at 348.75. The moving averages, exponential moving averages, MACD, RSI, Bollinger Bands, stochastic, ATR, OBV, Fibonacci levels, support and resistance, potential breakout, and volume statistics provide a comprehensive view of the stock's performance.
# ## Using tool: market_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"limit\": 100}"
# ## Tool Output:
# {'hold': 96, 'sell': 3, 'buy': 1}
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: market_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: market_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from news about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".          limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView news.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: retail_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: retail_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from TradingView Minds about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for in tradingview ex: "HDFCBANK","LTIM","RELIANCE".         limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView posts.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: Search the internet(**kwargs: Any) -> Any
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'title': 'Search Query', 'type': 'string'}}
# Tool Name: yf_fundamental_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_fundamental_analysis(ticker: 'string') -      Perform a comprehensive fundamental analysis on the given stock symbol.          Args:         ticker (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".          Returns:         dict: A dictionary with the detailed fundamental analysis results.
# Tool Arguments: {'ticker': {'title': 'Ticker', 'type': 'string'}}
# Tool Name: yf_tech_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_tech_analysis(stock_symbol: 'string', period: 'string') -      Perform a comprehensive technical analysis on the given stock symbol.          Args:         stock_symbol (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".         period (str): The time period for analysis. Default is "1y" (1 year).          Returns:         dict: A dictionary with the detailed technical analysis results.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'period': {'title': 'Period', 'type': 'string'}}
# Tool Name: tradingview_news_tool(*args: Any, **kwargs: Any) -> Any
# Tool Description: tradingview_news_tool(stock_symbol: 'string', max_articles: 'integer') -      Get the news articles from TradingView about a stock symbol.      Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".         max_articles (int): The maximum number of articles to fetch.      Returns:         list: A list containing the news articles from TradingView.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'max_articles': {'title': 'Max Articles', 'type': 'integer'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [market_sentiment_analysis, retail_sentiment_analysis, Search the internet, yf_fundamental_analysis, yf_tech_analysis, tradingview_news_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
#
#
# # Agent: Chief Investment Strategist
# ## Using tool: tradingview_news_tool
# ## Tool Input:
# "{\"stock_symbol\": \"BPCL\", \"max_articles\": 100}"
# ## Tool Output:
# ['Indian indices settled lower on Tuesday, dragged mainly by auto, metal, and pharmaceutical stocks. \nSeptember data showing inflation rose to a nine-month high also dampened investor sentiment as this could push domestic rate cuts to 2025 instead of December this year. \nAt close, the BSE Sensex fell 152.93, or 0.2%, to 81,820.12, while the NSE Nifty 50 slipped 70.60 points, or 0.3%, to 25,057.35. \nHDFC Life Insurance \nHDFCLIFE\n topped the losers on Tuesday, with shares slumping 4%, followed by Bajaj Auto (NSE:BAJAJ/AUTO, \nBAJAJ_AUTO\n) and Wipro \nWIPRO\n. \nConversely, Bharat Petroleum \nBPCL\n, ICICI Bank \nICICIBANK\n and Britannia Industries \nBRITANNIA\n were the top gainers. \nIn corporate news, APL Apollo Tubes \nAPLAPOLLO\n has raised 1 billion Indian rupees from the issue of commercial papers. \nMeanwhile, BEML \nBEML\n has bagged a contract worth 8.67 billion Indian rupees from Integral Coach Factory (ICF), Chennai.\n', '** Shares of Bharat Petroleum Corp Ltd \nBPCL\n, Indian Oil Corp Ltd \nIOC\n and Hindustan Petroleum Corp Ltd \nHINDPETRO\n up 2.6%, 2% and 4.5%, respectively \n** Global oil prices slid after a media report said Israel is willing not to strike Iranian oil targets, easing fears of a supply disruption \n** Lower oil prices benefit oil refiners such as BPCL, IOC and HPCL, which count crude as a major raw material\n** BPCL stock top pct gainer in blue-chip Nifty 50 \nNIFTY\n index\n** All three stocks rated "hold" on avg - LSEG data\n** HPCL leads YTD gains, up 137.4%; BPCL up 96% and top YTD gainer on NSEI, while IOC up 82%\n', 'PL Capital has come out with its second quarter (July-September’ 24) earnings estimates for the Oil & Gas sector. The brokerage house expects BPCL to report net profit at Rs. 3,260 crore down 61.6% year-on-year (up 8.2% quarter-on-quarter).\nNet Sales are expected to decrease by 4.2 percent Y-o-Y (down 12.8 percent Q-o-Q) to Rs. 98,610 crore, according to PL Capital.\nEarnings before interest, tax, depreciation and amortisation (EBITDA) are likely to fall by 52.2 percent Y-o-Y (up 9.2 percent Q-o-Q) to Rs. 6,170 crore.\nDisclaimer: The views and investment tips expressed by investment experts on moneycontrol.com are their own, and not that of the website or its management. Moneycontrol.com advises users to check with certified experts before taking any investment decisions.PL Capital_Oil & Gas\n', '', 'Sensex and Nifty closed in the red for the fifth session on October 4 amid worries about escalating conflict in the Middle East. Banking, FMCG, and auto stocks bore the brunt of the sell-off, while IT stocks offered a brief glimmer of hope amidst the market turmoil.\nAt close, the Sensex was down 808 points or 1 percent at 81,688 and the Nifty was down 200 points or 0.8 percent at 25,049. About 1,521 shares advanced, 2,266 shares declined, and 101 shares remained unchanged.\xa0Sensex and Nifty logged their biggest weekly drop since June 2022. This week, Nifty fell 4.3 percent and Sensex dropped 4.5 percent.\nConcerns over the escalating conflict in the Middle East have raised fears of potential disruptions to crude supplies from the top oil-producing region, pushing prices higher—a situation that impacts net importers like India.\xa0Brent Crude futures have surged over 9 percent so far in October to over $78 per barrel.\nMeanwhile, FIIs are diverting funds to China following its recent stimulus measures.\xa0The last three days have witnessed FIIs selling Rs 30,614 crores in the cash market. In just a week, China-dedicated funds have seen inflows worth over $13 billion while India-dedicated funds received just $107 million, Cameron Brandt, Director of Research at EPFR Global said in an interaction with CNBC-TV18.\nFollow our live blog for all the market action\n"The last three days have witnessed huge FII selling of Rs 30,614 crores in the cash market. FIIs are moving money from expensive India to cheap Hong Kong on expectations that the monetary and fiscal stimulus being i ...
#  Error parsing LLM output, agent will retry: I did it wrong. Invalid Format: I missed the 'Action:' after 'Thought:'. I will do right next, and don't use a tool I have already used.
#
# If you don't need to use any more tools, you must give your best complete final answer, make sure it satisfy the expect criteria, use the EXACT format below:
#
# Thought: I now can give a great answer
# Final Answer: my best complete final answer to the task.
#
#
#
#
# # Agent: Chief Investment Strategist
# ## Final Answer:
# Based on the sentiment analysis of news posts and market updates, it is evident that Bharat Petroleum Corporation Limited (BPCL) has been impacted by various factors such as escalating tensions in the Middle East, fluctuating crude oil prices, and global market conditions. The company's financial performance, including its gross refining margin (GRM) and net profit, has been influenced by these external factors. Additionally, the stock has experienced fluctuations in response to geopolitical events and global economic indicators. Considering these factors, it is important to conduct a thorough analysis of BPCL's financials, market sentiment, and technical indicators to make informed investment decisions.
#
#
# Based on the sentiment analysis of news posts and market updates, it is evident that Bharat Petroleum Corporation Limited (BPCL) has been impacted by various factors such as escalating tensions in the Middle East, fluctuating crude oil prices, and global market conditions. The company's financial performance, including its gross refining margin (GRM) and net profit, has been influenced by these external factors. Additionally, the stock has experienced fluctuations in response to geopolitical events and global economic indicators. Considering these factors, it is important to conduct a thorough analysis of BPCL's financials, market sentiment, and technical indicators to make informed investment decisions.

# %%
import os
import faiss
import numpy as np
import openai
from datetime import datetime
from crewai import Agent, Task, Crew, Process
from crewai_tools import SerperDevTool, ScrapeWebsiteTool, WebsiteSearchTool
from tools.sentiment_analysis_tool import retail_sentiment_analysis
from tools.yf_tech_analysis_tool import yf_tech_analysis
from tools.fundamental_analysis_tool import yf_fundamental_analysis
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from tools.search_tools import SearchTools  # Import the SearchTools class
from tools.news_tool import tradingview_news_tool  # Import the yahoo_news_tool
from crewai_tools import tool
from preprocessing import preprocess_text
from sentence_transformers import SentenceTransformer
import joblib
import requests
from bs4 import BeautifulSoup
from langchain_groq import ChatGroq

# Load environment variables
load_dotenv()

openai.api_key = os.getenv('OPENAI_API_KEY')

# Get TradingView news function
def get_tradingview_news(stock_symbol: str, max_articles: int = 5):
    """Fetch news articles from TradingView."""
    tvnewsdata = []
    url = f"https://news-headlines.tradingview.com/v2/view/headlines/symbol?client=web&lang=en&section=&streaming=true&symbol=NSE%3A{stock_symbol}"
    headers = {
        "sec-ch-ua": '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"',
        "Referer": "https://in.tradingview.com/",
        "sec-ch-ua-mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36",
        "sec-ch-ua-platform": '"Windows"'
    }

    response = requests.get(url, headers=headers)
    data = response.json()
    story_paths = [item['storyPath'] for item in data['items']]

    limit = 0
    for path in story_paths:
        iurl = "https://in.tradingview.com" + path
        response2 = requests.get(iurl, headers=headers)
        soup = BeautifulSoup(response2.content, "html.parser")
        news_content = "\n".join(p.get_text(separator="\n") for p in soup.find_all('p')[:-23])
        tvnewsdata.append(news_content)
        limit += 1
        if limit == max_articles:
            break

    return tvnewsdata

# Market sentiment analysis tool using TradingView news
@tool
def market_sentiment_analysis(stock_symbol: str, limit: int = 5):
    """
    Perform sentiment analysis on posts from news about a stock symbol.
    
    Args:
        stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE". 
        limit (int): Number of posts to fetch from TradingView.
    
    Returns:
        dict: Sentiment counts for TradingView news.
    """
    print(stock_symbol)
    sentiments_counts = {}
    pipeline, label_encoder = joblib.load(r'E:\Data Science\Capstone\Mindyourstock\text_classification_pipeline.pkl')

    tv_news = get_tradingview_news(stock_symbol, limit)
    for post in tv_news:
        sentiment = pipeline.predict([str(post)])[0]
        sentiment = label_encoder.inverse_transform([sentiment])[0]

        if sentiment not in sentiments_counts:
            sentiments_counts[sentiment] = 0
        sentiments_counts[sentiment] += 1

    return sentiments_counts

# Initialize different LLM models based on user selection
def initialize_llm(model_option, api_key):
    if model_option == 'gpt-3.5-turbo-1106':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-3.5-turbo-1106', temperature=0.1)
    elif model_option == 'OpenAI GPT-4o Mini':
        return ChatOpenAI(openai_api_key=api_key, model='gpt-4o-mini', temperature=0.1)
    elif model_option == 'llama3-8b-8192':
        return ChatGroq(groq_api_key=api_key, model='groq/llama3-8b-8192', temperature=0.1)
    else:
        raise ValueError("Invalid model option selected")

# FAISS index initialization
embedding_dim = 768
index_file = './faiss_index.index'

# Check if FAISS index already exists, else create a new one
if os.path.exists(index_file):
    index = faiss.read_index(index_file)
else:
    index = faiss.IndexFlatL2(embedding_dim)

# Store for metadata (query-response pairs)
query_response_metadata = []

# Sentence Transformer model for embeddings
model = SentenceTransformer('sentence-transformers/bert-base-nli-mean-tokens')

# Function to get embeddings from text
def get_embeddings(text):
    """Generate embeddings for the text using HuggingFace's model."""
    embedding = model.encode(text)
    return np.array(embedding)

# Function to store query-response pairs in FAISS
def store_query_response(query, response):
    """Store the query and response in the FAISS vector DB."""
    # Generate embeddings for the query
    query_embedding = get_embeddings(query)

    # Add the embedding to the FAISS index
    index.add(np.array([query_embedding], dtype=np.float32))

    # Save the query and response in metadata
    query_response_metadata.append({
        'query': query,
        'response': response
    })

    # Persist the FAISS index and metadata
    faiss.write_index(index, index_file)
    with open('query_response_metadata.npy', 'wb') as f:
        np.save(f, query_response_metadata)

# Function to load stored metadata
def load_metadata():
    """Load stored metadata."""
    if os.path.exists('query_response_metadata.npy'):
        with open('query_response_metadata.npy', 'rb') as f:
            return np.load(f, allow_pickle=True).tolist()
    return []

# Function to find a similar response from FAISS index
def find_similar_response(query):
    """Find a similar response from the FAISS index."""
    query_embedding = get_embeddings(query)
    distances, indices = index.search(np.array([query_embedding], dtype=np.float32), k=1)

    if distances[0][0] < 1.0:
        similar_query = query_response_metadata[indices[0][0]]['query']
        similar_response = query_response_metadata[indices[0][0]]['response']
        return similar_response, similar_query
    return None, None

# Load stored metadata if it exists
query_response_metadata = load_metadata()

# Function to handle dynamic user queries and responses
def handle_query(user_query, model_option, api_key):
    # Self-reflection and check for similar response
    stored_response, similar_query = find_similar_response(user_query)
    if stored_response is not None:
        current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
        os.makedirs('./crew_results', exist_ok=True)
        file_path = f"./crew_results/crew_result_{current_time}.pdf"
        result_str = str(stored_response)
        with open(file_path, 'w', encoding='utf-8') as file:
            file.write(result_str)
        return f"{stored_response}"
    
    

    # Initialize selected LLM
    llm = initialize_llm(model_option, api_key)

    # Initialize tools
    retail_sentiment_tool = retail_sentiment_analysis
    serper_tool = SerperDevTool()
    market_sentiment_tool = market_sentiment_analysis
    yf_tech_tool = yf_tech_analysis
    yf_fundamental_tool = yf_fundamental_analysis
    news_tool = tradingview_news_tool

    # Define Agents with Tree of Thought (ToT) evaluation for better reflection and exploration
    converser = Agent(
        role='Financial Data Analyst',
        goal='Dynamically respond to queries using available tools',
        verbose=True,
        memory=True,
        backstory="An expert in financial analysis with deep understanding of various analytic tools, you're adept at providing dynamic and insightful information.",
        tools=[news_tool, yf_fundamental_tool, yf_tech_tool, retail_sentiment_tool, market_sentiment_tool, serper_tool],
        llm=llm,
        tree_of_thought=True  # Enabling Tree of Thought exploration
    )

    researcher = Agent(
        role='Senior Stock Market Researcher',
        goal='Gather and analyze comprehensive data about stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a Ph.D. in Financial Economics and 15 years of experience in equity research, you're known for your meticulous data collection and insightful analysis.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, news_tool],
        llm=llm,
        tree_of_thought=True  # Multiple hypotheses exploration
    )

    technical_analyst = Agent(
        role='Expert Technical Analyst',
        goal='Perform an in-depth technical analysis on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a Chartered Market Technician (CMT) with 15 years of experience, you have a keen eye for chart patterns and market trends.",
        tools=[yf_tech_tool],
        llm=llm,
        tree_of_thought=True  # Explore different technical indicators and scenarios
    )

    fundamental_analyst = Agent(
        role='Senior Fundamental Analyst',
        goal='Conduct a comprehensive fundamental analysis of stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="With a CFA charter and 15 years of experience in value investing, you dissect financial statements and identify key value drivers.",
        tools=[yf_fundamental_tool],
        llm=llm,
        tree_of_thought=True  # Explore different valuation methods and financial metrics
    )

    reporter = Agent(
        role='Chief Investment Strategist',
        goal='Synthesize all analyses to create a definitive investment report on stock_symbol mentioned in {user_query}',
        verbose=True,
        memory=True,
        backstory="As a seasoned investment strategist with 20 years of experience, you weave complex financial data into compelling investment narratives.",
        tools=[market_sentiment_tool, retail_sentiment_tool, serper_tool, yf_fundamental_tool, yf_tech_tool, news_tool],
        llm=llm,
        tree_of_thought=True
    )

    # Dynamically determine which agents to use based on the query content


        # Task for dynamic interaction
    dynamic_task = Task(
        description=(
            "Analyze and respond to the query: {user_query}. Include:\n"
            "tool output in the response"
        ),
        expected_output='Provide a dynamic, interactive response with the data you have available',
        agent=converser
    )
    
    # Task Definitions
    research_task = Task(
        description=(
            "Conduct research on stock symbol in the {user_query}. Your analysis should include:\n"
            "1. Current stock price and historical performance (5 years).\n"
            "2. Key financial metrics (P/E, EPS growth, revenue growth, margins).\n"
            "3. Recent news and press releases (1 month).\n"
            "4. Analyst ratings and price targets (min 3 analysts).\n"
            "5. market sentiment analysis.\n"
            "6. retail sentiment analysis.\n"
            "7. Major institutional holders and recent changes.\n"
            "8. Competitive landscape and market share.\n"
            "Use reputable financial websites for data."
        ),
        expected_output='A detailed 150-word research report with data sources and brief analysis.',
        agent=researcher
    )
    technical_analysis_task = Task(
        description=(
            "Perform technical analysis on stock_symbol mentioned in {user_query}. Include:\n"
            "1. 50-day and 200-day moving averages (1 year).\n"
            "2. Key support and resistance levels (3 each).\n"
            "3. RSI and MACD indicators.\n"
            "4. Volume analysis (3 months).\n"
            "5. Significant chart patterns (6 months).\n"
            "6. Fibonacci retracement levels.\n"
            "7. Comparison with sector's average.\n"
            "Use the yf_tech_analysis tool for data."
        ),
        expected_output='A 100-word technical analysis report with buy/sell/hold signals and annotated charts.',
        agent=technical_analyst
    )
    fundamental_analysis_task = Task(
        description=(
            "Conduct fundamental analysis of stock_symbol mentioned in {user_query}. Include:\n"
            "1. Review last 3 years of financial statements.\n"
            "2. Key ratios (P/E, P/B, P/S, PEG, Debt-to-Equity, etc.).\n"
            "3. Comparison with main competitors and industry averages.\n"
            "4. Revenue and earnings growth trends.\n"
            "5. Management effectiveness (ROE, capital allocation).\n"
            "6. Competitive advantages and market position.\n"
            "7. Growth catalysts and risks (2-3 years).\n"
            "8. DCF valuation model with assumptions.\n"
            "Use yf_fundamental_analysis tool for data."
        ),
        expected_output='A 100-word fundamental analysis report with buy/hold/sell recommendation and key metrics summary.',
        agent=fundamental_analyst
    )
    report_task = Task(
        description=(
            "Create an investment report on stock_symbol mentioned in {user_query}. Include:\n"
            "1. Executive Summary: Investment recommendation.\n"
            "2. Company Snapshot: Key facts.\n"
            "3. Financial Highlights: Top metrics and peer comparison.\n"
            "4. Technical Analysis: Key findings.\n"
            "5. Fundamental Analysis: Top strengths and concerns.\n"
            "6. Risk and Opportunity: Major risk and growth catalyst.\n"
            "7. Sentiment: Key takeaway from sentiment analysis, including the number of positive, negative and neutral comments and total comments.\n"
            "8. Investment Thesis: Bull and bear cases.\n"
            "9. Price Target: 12-month forecast.\n"
        ),
        expected_output='A 600-word investment report with clear sections, key insights.',
        agent=reporter
    )
        
    selected_agents = []
    selected_tasks = []
    if 'technical analysis' in user_query.lower():
        selected_agents.append(technical_analyst)
        selected_tasks.append(technical_analysis_task)
    if 'fundamental analysis' in user_query.lower():
        selected_agents.append(fundamental_analyst)
        selected_tasks.append(fundamental_analysis_task)
    if 'market sentiment' in user_query.lower() or 'sentiment' in user_query.lower() or 'sentiment analysis' in user_query.lower():
        selected_agents.append(researcher)
        selected_tasks.append(research_task)
    if 'detailed report' in user_query.lower() or 'detailed analysis' in user_query.lower() or 'detailed report' in user_query.lower() or 'investment report' in user_query.lower():
        selected_agents.extend([researcher,technical_analyst,fundamental_analyst,reporter])
        selected_tasks.extend([research_task,technical_analysis_task,fundamental_analysis_task,report_task])    
    if not selected_agents:  # If no specific keyword is found, default to using all agents
        selected_agents = [converser]
        selected_tasks.append(dynamic_task)

    # Create Crew for multi-agent collaboration with recursive feedback and ToT reasoning
    market_analysis_crew = Crew(
        title="Dynamic Stock Market Analysis Crew",
        description="The crew handles stock market analysis using sentiment, technical, and fundamental data.", # Agents perform tasks sequentially with cross-agent evaluations
        agents=selected_agents,
        tasks=selected_tasks,
        process=Process.sequential,
        review_phase=True,  # Recursive review phase to evaluate and refine responses
        cache=True
    )

    result = market_analysis_crew.kickoff(inputs={
        'user_query': user_query
    })
    current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    os.makedirs('./crew_results', exist_ok=True)
    file_path = f"./crew_results/crew_result_{current_time}.pdf"
    result_str = str(result)
    with open(file_path, 'w') as file:
        file.write(result_str)
    
    # Store the result in FAISS
    final_response = result
    
    # Store the query and response in FAISS
    store_query_response(user_query, final_response)
    return final_response

# %%
# Example Usage
query = "give me detailed report of vedanta?"
model_option = 'gpt-3.5-turbo-1106'
response = handle_query(query, model_option, os.getenv('OPENAI_API_KEY'))
print(response)
# Out:
# 2024-10-16 11:57:17,872 - 1712 - __init__.py-__init__:538 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Senior Stock Market Researcher
# ## Task: Conduct research on stock symbol in the give me detailed report of vedanta?. Your analysis should include:
# 1. Current stock price and historical performance (5 years).
# 2. Key financial metrics (P/E, EPS growth, revenue growth, margins).
# 3. Recent news and press releases (1 month).
# 4. Analyst ratings and price targets (min 3 analysts).
# 5. market sentiment analysis.
# 6. retail sentiment analysis.
# 7. Major institutional holders and recent changes.
# 8. Competitive landscape and market share.
# Use reputable financial websites for data.
#
#
# # Agent: Senior Stock Market Researcher
# ## Thought: I need to gather comprehensive data about the stock symbol "VEDL" (Vedanta Limited) to provide a detailed research report. I will need to collect information on the current stock price, historical performance, key financial metrics, recent news and press releases, analyst ratings and price targets, market sentiment analysis, retail sentiment analysis, major institutional holders and recent changes, and the competitive landscape and market share.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"VEDL stock price\"}"
# ## Tool Output:
#
# Search results: Title: Vedanta Ltd. - Share/Stock Price - Moneycontrol
# Link: https://www.moneycontrol.com/india/stockpricequote/miningminerals/vedanta/SG
# Snippet: Open. 490.05 · Previous Close. 489.85 · UC Limit. 538.80 · LC Limit. 440.90 · Volume. 1257690 · VWAP. 493.55 · Mkt Cap (Rs. Cr.) 193,501 · 20D Avg Volume. 12,156,463.
# ---
# Title: Vedanta Limited (VEDL.NS) Stock Price, News, Quote & History
# Link: https://finance.yahoo.com/quote/VEDL.NS/
# Snippet: 10,785.56% · Previous Close 499.15 · Open 500.00 · Bid -- · Ask -- · Day's Range 486.40 - 500.95 · 52 Week Range 211.20 - 523.65 · Volume 7,408,151 · Avg.
# ---
# Title: VEDL: Vedanta Ltd - Stock Price, Quote and News - CNBC
# Link: https://www.cnbc.com/quotes/VEDL
# Snippet: Vedanta Ltd VEDL:National Stock Exchange of India · Open500.00 · Day High507.05 · Day Low494.25 · Prev Close497.50 · 52 Week High523.65 · 52 Week High Date09/30 ...
# ---
# Title: VEDL Stock Price and Chart — NSE:VEDL - TradingView
# Link: https://www.tradingview.com/symbols/NSE-VEDL/
# Snippet: The current price of VEDL is 489.85 INR — it has increased by 0.33% in the past 24 hours. Watch VEDANTA LTD stock price performance more closely on the chart.
# ---
# Title: Vedanta Ltd share price | About Vedanta | Key Insights - Screener
# Link: https://www.screener.in/company/VEDL/consolidated/
# Snippet: 1. Coal India, 496.45 ; 2. Vedanta, 491.90 ; 3. NMDC, 232.05 ; 4. Lloyds Metals, 1011.15 ...
# ---
# Title: Vedanta Limited Share Price Today, Live NSE Stock Price, News
# Link: http://www.nseindia.com/get-quotes/equity?symbol=VEDL
# Snippet: Shareholding Patterns (in %) ; Promoter & Promoter Group, 56.38, 59.32 ; Public, 43.45, 40.51 ; Shares held by Employee Trusts, 0.17, 0.18 ; Total, 100.00, 100.00 ...
# ---
# Title: VEDL - Vedanta Ltd - ADR (NYSE) - Share Price and News - Fintel
# Link: https://fintel.io/s/us/vedl
# Snippet: The share price of Vedanta Ltd - ADR as of November 8, 2021 is $16.50 / share. The Factor Analysis chart (below right) shows a ...
# ---
# Title: Vedanta Ltd Stock Price Today | NYSE: VEDL Live - Investing.com
# Link: https://www.investing.com/equities/sesa-sterlit-ltd
# Snippet: The Vedanta Ltd stock price today is 16.50. What Is the Stock Symbol for Vedanta Ltd? The stock ticker symbol for Vedanta Ltd is VEDL. Is VEDL the Same as $VEDL ...
# ---
# Title: Vedanta Limited (VEDL.NS) Stock Historical Prices & Data
# Link: https://finance.yahoo.com/quote/VEDL.NS/history/
# Snippet: Vedanta Limited (VEDL.NS) ; Aug 8, 2024, 430.05, 431.50 ; Aug 7, 2024, 425.50, 434.45 ; Aug 6, 2024, 417.55, 421.95 ; Aug 5, 2024, 424.00, 428.45 ...
# ---
# Title: Vedanta | VEDL - Stock Price | Live Quote | Historical Chart
# Link: https://tradingeconomics.com/vedl:in
# Snippet: Vedanta traded at 497.40 this Friday October 11th, increasing 5.10 or 1.04 percent since the previous trading session. Looking back, over the last four weeks, ...
# ---
#
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"VEDL key financial metrics\"}"
# ## Tool Output:
#
# Search results: Title: Vedanta Limited (VEDL.NS) Valuation Measures & Financial Statistics
# Link: https://finance.yahoo.com/quote/VEDL.NS/key-statistics/
# Snippet: Find out all the key statistics for Vedanta Limited (VEDL.NS), including valuation measures, fiscal year financial statistics, trading record, ...
# ---
# Title: Vedanta Key Financial Ratios, Vedanta Financial Statement ...
# Link: https://www.moneycontrol.com/financials/vedanta/ratiosVI/SG
# Snippet: Financials ; Key Financial Ratios of Vedanta (in Rs. Cr.) Mar 24, Mar 23 ; Per Share Ratios ; Basic EPS (Rs.) 17.80, 73.54 ; Diluted EPS (Rs.) 17.80, 73.54 ; Cash ...
# ---
# Title: Find Key Metrics, Vedanta Financial Ratios and Highlights - Mint
# Link: https://www.livemint.com/vedanta/key-metrics/companyid-s0003041
# Snippet: Vedanta Key Metrics ; Revenue/employee - trailing 12 month, 19,45,26,900.00 ; Return on average assets - 5 year average, 6.29 ; Net Income/employee - most recent ...
# ---
# Title: Vedanta (NSE: VEDL) Financial Ratios and Metrics - Stock Analysis
# Link: https://stockanalysis.com/quote/nse/VEDL/financials/ratios/
# Snippet: Financial ratios and metrics for Vedanta (NSE: VEDL). Includes annual, quarterly and trailing numbers with full history and charts.
# ---
# Title: Vedanta Ltd (VEDL) Financial Ratios - Investing.com
# Link: https://www.investing.com/equities/sesa-sterlit-ltd-ratios
# Snippet: This VEDL page provides a table containing critical financial ratios such as P/E Ratio, EPS, ROI, and others.
# ---
# Title: Key Performance Indicators - Vedanta Limited
# Link: https://www.vedantalimited.com/vedantaFY23/key-performance-indicators.html
# Snippet: KEY FINANCIAL RATIOS. Debtors' turnover ratio*. Description: The debtors' turnover ratio is an accounting measure used to quantify a company's effectiveness ...
# ---
# Title: Vedanta Limited (VEDL.BO) Valuation Measures & Financial Statistics
# Link: https://finance.yahoo.com/quote/VEDL.BO/key-statistics/
# Snippet: Find out all the key statistics for Vedanta Limited (VEDL.BO), including valuation measures, fiscal year financial statistics, trading record, ...
# ---
# Title: Vedanta (VEDL) Balance Sheet & Financial Health Metrics
# Link: https://simplywall.st/stocks/in/materials/nse-vedl/vedanta-shares/health
# Snippet: Vedanta has a total shareholder equity of ₹420.7B and total debt of ₹727.7B, which brings its debt-to-equity ratio to 173%.
# ---
# Title: VEDANTA LTD Statistics – NSE:VEDL - TradingView
# Link: https://www.tradingview.com/symbols/NSE-VEDL/financials-statistics-and-ratios/
# Snippet: VEDL price-to-sales ratio is 1.19. The company has an Enterprise Value to EBITDA ratio of 4.68. As of 2023 they employed 97.02 k people. Statistics.
# ---
# Title: VEDL.IN | Vedanta Ltd. Financial Statements - WSJ
# Link: https://www.wsj.com/market-data/quotes/IN/XNSE/VEDL/financials
# Snippet: Gross Margin +26.70. Operating Margin +18.80. Pretax Margin +14.00. Net Margin +2.91. Return on Assets 2.19. Return on Equity 12.09.
# ---
#
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: tradingview_news_tool
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"max_articles\": 10}"
# ## Tool Output:
# ["Let's catch up on the latest news from the stock market. From significant investments to major deals, quarterly earnings, fund raising and appointments, here’s a quick look at which stocks will be in focus in today's trade:\nResults Today\nTata Consultancy Services, Tata Elxsi, Indian Renewable Energy Development Agency, Anand Rathi Wealth, Den Networks, Arkade Developers, Ashoka Metcast, GM Breweries, Hathway Bhawani Cabletel, Infomedia Press, NB Footwear, and Reliance Naval and Engineering will release their quarterly earnings on October 10.\nQuarterly Earnings\nGTPL Hathway Q2 Consolidated (YoY)\nNet profit falls 61.7% to Rs 13.74 crore Vs Rs 35.9 crore\nRevenue increases 9.8% to Rs 855.6 crore Vs Rs 779.2 crore\nEBITDA declines 13.6% to Rs 107.4 crore Vs Rs 124.3 crore\nMargin drops to 12.55% Vs 16%\nStocks To Watch\nBritannia Industries\nThe company has announced a further strategic partnership with Bel Group for local cheese manufacturing in India. The factory at Ranjangaon, Maharashtra, will produce 10,000 tons of Britannia The Laughing Cow cheese products every year to meet the growing demands of Indian consumers. The joint venture will invest Rs 220 crore in the cheese plant.\nPNC Infratech\nThe company has emerged as the lowest bidder in an EPC project worth Rs 2,090.6 crore from the City & Industrial Development Corporation of Maharashtra (CIDCO). The project involves infrastructure development of 20-meter-wide roads, construction of various major and minor structures (flyovers, minor bridges, VUPS, PUPS, etc.), and allied electrical works (street lights) in TPS-8,\xa09, and TPS-12 under the NAINA project.\nRashtriya Chemicals and Fertilizers\nRCF has approved awarding an order worth Rs 1,000.3 crore to Larsen & Toubro for setting up a 1200 MTPD (DAP basis) complex fertilizer plant on an LSTK basis at RCF, Thal.\nSonata Software\nThe company has announced a strategic partnership with insurance technology provider iNube to enhance go-to-market efforts for insurers in the US and UK.\nJM Financial\nThe Competition Commission of India (CCI) has approved the Tranche 1 acquisition of 42.99% shareholding in JM Financial Credit Solutions (JMFCSL) by JM Financial for Rs 1,282 crore. Post acquisition of Tranche 1, JM Financial's shareholding in JMFCSL will increase from 46.68% to 89.67%. Additionally, the CCI has also approved the acquisition of 71.79% shareholding in JM Financial Asset Reconstruction Company (JMFARC) by JMFCSL from JM Financial for Rs 856 crore. Following the stake sale, JM Financial's shareholding in JMFARC will become nil, and JMFARC will cease to be a direct subsidiary of the company.\nIndian Railway Finance Corporation\nIRFC has appointed Manoj Kumar Dubey as an Additional Director to be designated as Chairman and Managing Director on the board of IRFC. He is also designated as CEO of the company for five years.\nAdani Enterprises\nThe company has opened its Qualified Institutions Placement (QIP) issue and set the floor price at Rs 3,117.475 per share. According to CNBC-TV18 sources, the QIP issue size may be Rs 4,200 crore.\nGR Infraprojects\nThe company has received a Letter of Acceptance for a project worth Rs 903.53 crore from the Maharashtra Metro Rail Corporation (Nagpur Metro Rail Project). The project involves the design and construction of an elevated metro viaduct.\nRain Industries\nCompany's subsidiary, Rain Carbon Inc, has signed an agreement with Northern Graphite Corporation to jointly develop and commercialize advanced battery anode material (BAM) used in lithium-ion batteries for electric vehicles.\nZee Entertainment Enterprises\nThe Independent Investigation Committee constituted by the Board of ZEE submitted its report to the Board. The Committee noted that the transactions under investigation did not adversely affect the company or its shareholders. The transactions were found to be part of the normal course of business, and no material irregularities were reported. The committee did ...
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: market_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: market_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from news about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".          limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView news.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: retail_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: retail_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from TradingView Minds about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for in tradingview ex: "HDFCBANK","LTIM","RELIANCE".         limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView posts.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: Search the internet(**kwargs: Any) -> Any
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'title': 'Search Query', 'type': 'string'}}
# Tool Name: tradingview_news_tool(*args: Any, **kwargs: Any) -> Any
# Tool Description: tradingview_news_tool(stock_symbol: 'string', max_articles: 'integer') -      Get the news articles from TradingView about a stock symbol.      Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".         max_articles (int): The maximum number of articles to fetch.      Returns:         list: A list containing the news articles from TradingView.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'max_articles': {'title': 'Max Articles', 'type': 'integer'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [market_sentiment_analysis, retail_sentiment_analysis, Search the internet, tradingview_news_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# VEDL
#
#
# # Agent: Senior Stock Market Researcher
# ## Thought: Thought: I need to analyze the market sentiment for the stock symbol "VEDL" to understand the overall sentiment from news and retail investors.
# ## Using tool: market_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"limit\": 100}"
# ## Tool Output:
# {'hold': 92, 'sell': 7, 'Strong buy': 1}
#
#
# # Agent: Senior Stock Market Researcher
# ## Using tool: retail_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"limit\": 100}"
# ## Tool Output:
# {'neutral': 7, 'negative': 1, 'positive': 2}
#
#
# # Agent: Senior Stock Market Researcher
# ## Final Answer:
# After analyzing the market sentiment for the stock symbol "VEDL" from news and retail investors, it is observed that from news sentiment analysis, there are 92 "hold" sentiments, 7 "sell" sentiments, and 1 "strong buy" sentiment. From retail sentiment analysis, there are 7 "neutral" sentiments, 1 "negative" sentiment, and 2 "positive" sentiments. This indicates a predominantly neutral sentiment from retail investors, while news sentiment leans towards a "hold" sentiment with a few "sell" sentiments.
#
#
# # Agent: Expert Technical Analyst
# ## Task: Perform technical analysis on stock_symbol mentioned in give me detailed report of vedanta?. Include:
# 1. 50-day and 200-day moving averages (1 year).
# 2. Key support and resistance levels (3 each).
# 3. RSI and MACD indicators.
# 4. Volume analysis (3 months).
# 5. Significant chart patterns (6 months).
# 6. Fibonacci retracement levels.
# 7. Comparison with sector's average.
# Use the yf_tech_analysis tool for data.
# [*********************100%***********************]  1 of 1 completed
# # Agent: Expert Technical Analyst
# ## Thought: I need to gather the technical analysis data for the stock symbol "VEDL" to provide a comprehensive report including moving averages, support and resistance levels, RSI and MACD indicators, volume analysis, chart patterns, Fibonacci retracement levels, and comparison with the sector's average.
# ## Using tool: yf_tech_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL.NS\", \"period\": \"1y\"}"
# ## Tool Output:
# {'Current_Price': 488.6000061035156, 'Moving_Averages': {'20_MA': 488.8375045776367, '50_MA': 463.75599975585936, '100_MA': 457.08000091552736, '200_MA': 383.82724960327147}, 'Exponential_MAs': {'12_EMA': 493.35403265759123, '26_EMA': 483.9412998093624, '50_EMA': 471.04507194644214, '200_EMA': 398.76667002028006}, 'MACD': {'MACD': 9.412732848228814, 'Signal_Line': 11.70324072680735, 'Histogram': -2.290507878578536}, 'RSI': 55.61978339372823, 'Bollinger_Bands': {'Upper': 534.3246252755124, 'Middle': 488.8375045776367, 'Lower': 443.350383879761}, 'Stochastic': {'%K': 24.86602364996585, '%D': 40.28225925112181}, 'ATR': 15.303575788225446, 'OBV': 381008794.0, 'Fibonacci_Levels': {'0%': 523.6500244140625, '23.6%': 449.9118179321289, '38.2%': 404.29411392211915, '50%': 367.42501068115234, '61.8%': 330.55590744018554, '100%': 211.1999969482422}, 'Support_Resistance': {'Support': 437.0, 'Resistance': 523.6500244140625}, 'Potential_Breakout': 'No Breakout', 'Trend': 'Bullish', 'Volume': {'Current': 2824169, 'MA': 14490816.8, 'Trend': 'Below Average'}, 'Statistics': {'Yearly_High': 523.6500244140625, 'Yearly_Low': 211.1999969482422, 'Average_Volume': 14539936.80894309, 'Volatility': 0.36555786411955105}, 'Interpretation': {'Trend': 'Bullish', 'RSI': 'Neutral', 'MACD': 'Bearish', 'Stochastic': 'Neutral', 'Bollinger_Bands': 'Neutral', 'Volume': 'Low'}}
#
#
# # Agent: Expert Technical Analyst
# ## Final Answer:
# Based on the technical analysis, the recommendation for VEDL.NS is to "hold". The stock is currently exhibiting a neutral to bearish sentiment in the short term, with potential support at 449.91. The MACD indicator and the stock's position relative to the Bollinger Bands indicate a bearish sentiment. The RSI and Stochastic indicators suggest a neutral sentiment. The stock is currently below the 20-day exponential moving average, indicating a short-term bearish trend. The volume analysis also indicates a low volume trend.
#
#
# # Agent: Senior Fundamental Analyst
# ## Task: Conduct fundamental analysis of stock_symbol mentioned in give me detailed report of vedanta?. Include:
# 1. Review last 3 years of financial statements.
# 2. Key ratios (P/E, P/B, P/S, PEG, Debt-to-Equity, etc.).
# 3. Comparison with main competitors and industry averages.
# 4. Revenue and earnings growth trends.
# 5. Management effectiveness (ROE, capital allocation).
# 6. Competitive advantages and market position.
# 7. Growth catalysts and risks (2-3 years).
# 8. DCF valuation model with assumptions.
# Use yf_fundamental_analysis tool for data.
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:25: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   financials = stock.financials.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:26: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   balance_sheet = stock.balance_sheet.fillna(0).infer_objects(copy=False)
# e:\Data Science\Capstone\Mindyourstock\tools\fundamental_analysis_tool.py:27: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cash_flow = stock.cashflow.fillna(0).infer_objects(copy=False)
# # Agent: Senior Fundamental Analyst
# ## Thought: I need to use the yf_fundamental_analysis tool to gather the necessary data for conducting a comprehensive fundamental analysis of Vedanta.
# ## Using tool: yf_fundamental_analysis
# ## Tool Input:
# "{\"ticker\": \"VEDL.NS\"}"
# ## Tool Output:
# {'Company Name': 'Vedanta Limited', 'Sector': 'Basic Materials', 'Industry': 'Other Industrial Metals & Mining', 'Key Ratios': {'P/E Ratio': 35.140186, 'Forward P/E': 10.539025, 'P/B Ratio': 5.9017425, 'P/S Ratio': 1.3493648, 'PEG Ratio': -5.84, 'Debt to Equity': 172.98, 'Current Ratio': 0, 'Quick Ratio': 0, 'ROE': 0, 'ROA': 0, 'ROIC': 0, 'Gross Margin': 0.51083, 'Operating Margin': 0.23121999, 'Net Profit Margin': 0.03613, 'Dividend Yield': 0.0939, 'Payout Ratio': 1.5816001}, 'Growth Rates': {'Revenue Growth (YoY)': -0.024834254903579045, 'Net Income Growth (YoY)': -0.5991110270474749}, 'Valuation Metrics': {'Market Cap': 1944016257024, 'Enterprise Value': 2532960108544, 'EV/EBITDA': 6.434, 'EV/Revenue': 1.758}, 'Future Estimates': {'Next Year EPS Estimate': 46.38, 'Next Year Revenue Estimate': 0, 'Long-term Growth Rate': 0.03}, 'Simple DCF Valuation': 2506233545505.8896, 'Last Updated': '2024-03-31', 'Data Retrieval Date': '2024-10-16', 'Interpretations': {'P/E Ratio': 'High P/E might indicate overvaluation or high growth expectations', 'Debt to Equity': 'High leverage', 'ROE': 'Potential profitability issues', 'Revenue Growth': 'Slowing growth'}}
#
#
# # Agent: Senior Fundamental Analyst
# ## Final Answer:
# Vedanta Limited operates in the Basic Materials sector, specifically in the Other Industrial Metals & Mining industry. The company's key ratios reveal a P/E ratio of 35.14, indicating potential overvaluation or high growth expectations, and a high debt-to-equity ratio of 172.98, signifying significant leverage. The revenue growth (YoY) is negative at -2.48%, and the net income growth (YoY) is at -59.91%, indicating slowing growth and potential profitability issues. The company's DCF valuation stands at approximately 2.51 trillion, suggesting a current market undervaluation. Considering the high P/E and debt levels, caution is advised, and a "hold" recommendation is appropriate pending further analysis.
#
#
# # Agent: Chief Investment Strategist
# ## Task: Create an investment report on stock_symbol mentioned in give me detailed report of vedanta?. Include:
# 1. Executive Summary: Investment recommendation.
# 2. Company Snapshot: Key facts.
# 3. Financial Highlights: Top metrics and peer comparison.
# 4. Technical Analysis: Key findings.
# 5. Fundamental Analysis: Top strengths and concerns.
# 6. Risk and Opportunity: Major risk and growth catalyst.
# 7. Sentiment: Key takeaway from sentiment analysis, including the number of positive, negative and neutral comments and total comments.
# 8. Investment Thesis: Bull and bear cases.
# 9. Price Target: 12-month forecast.
#
#
#
# # Agent: Chief Investment Strategist
# ## Thought: I need to gather comprehensive information on Vedanta Limited to create a well-rounded investment report. This will involve analyzing the company's financials, technical and fundamental aspects, market sentiment, and potential risks and opportunities.
# ## Using tool: yf_fundamental_analysis
# ## Tool Input:
# "{\"ticker\": \"VEDL.NS\"}"
# ## Tool Output:
# {'Company Name': 'Vedanta Limited', 'Sector': 'Basic Materials', 'Industry': 'Other Industrial Metals & Mining', 'Key Ratios': {'P/E Ratio': 35.140186, 'Forward P/E': 10.539025, 'P/B Ratio': 5.9017425, 'P/S Ratio': 1.3493648, 'PEG Ratio': -5.84, 'Debt to Equity': 172.98, 'Current Ratio': 0, 'Quick Ratio': 0, 'ROE': 0, 'ROA': 0, 'ROIC': 0, 'Gross Margin': 0.51083, 'Operating Margin': 0.23121999, 'Net Profit Margin': 0.03613, 'Dividend Yield': 0.0939, 'Payout Ratio': 1.5816001}, 'Growth Rates': {'Revenue Growth (YoY)': -0.024834254903579045, 'Net Income Growth (YoY)': -0.5991110270474749}, 'Valuation Metrics': {'Market Cap': 1944016257024, 'Enterprise Value': 2532960108544, 'EV/EBITDA': 6.434, 'EV/Revenue': 1.758}, 'Future Estimates': {'Next Year EPS Estimate': 46.38, 'Next Year Revenue Estimate': 0, 'Long-term Growth Rate': 0.03}, 'Simple DCF Valuation': 2506233545505.8896, 'Last Updated': '2024-03-31', 'Data Retrieval Date': '2024-10-16', 'Interpretations': {'P/E Ratio': 'High P/E might indicate overvaluation or high growth expectations', 'Debt to Equity': 'High leverage', 'ROE': 'Potential profitability issues', 'Revenue Growth': 'Slowing growth'}}
#
#
# # Agent: Chief Investment Strategist
# ## Using tool: yf_tech_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL.NS\", \"period\": \"1y\"}"
# ## Tool Output:
# {'Current_Price': 488.6000061035156, 'Moving_Averages': {'20_MA': 488.8375045776367, '50_MA': 463.75599975585936, '100_MA': 457.08000091552736, '200_MA': 383.82724960327147}, 'Exponential_MAs': {'12_EMA': 493.35403265759123, '26_EMA': 483.9412998093624, '50_EMA': 471.04507194644214, '200_EMA': 398.76667002028006}, 'MACD': {'MACD': 9.412732848228814, 'Signal_Line': 11.70324072680735, 'Histogram': -2.290507878578536}, 'RSI': 55.61978339372823, 'Bollinger_Bands': {'Upper': 534.3246252755124, 'Middle': 488.8375045776367, 'Lower': 443.350383879761}, 'Stochastic': {'%K': 24.86602364996585, '%D': 40.28225925112181}, 'ATR': 15.303575788225446, 'OBV': 381008794.0, 'Fibonacci_Levels': {'0%': 523.6500244140625, '23.6%': 449.9118179321289, '38.2%': 404.29411392211915, '50%': 367.42501068115234, '61.8%': 330.55590744018554, '100%': 211.1999969482422}, 'Support_Resistance': {'Support': 437.0, 'Resistance': 523.6500244140625}, 'Potential_Breakout': 'No Breakout', 'Trend': 'Bullish', 'Volume': {'Current': 2824169, 'MA': 14490816.8, 'Trend': 'Below Average'}, 'Statistics': {'Yearly_High': 523.6500244140625, 'Yearly_Low': 211.1999969482422, 'Average_Volume': 14539936.80894309, 'Volatility': 0.36555786411955105}, 'Interpretation': {'Trend': 'Bullish', 'RSI': 'Neutral', 'MACD': 'Bearish', 'Stochastic': 'Neutral', 'Bollinger_Bands': 'Neutral', 'Volume': 'Low'}}
#
#
# # Agent: Chief Investment Strategist
# ## Using tool: tradingview_news_tool
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"max_articles\": 10}"
# ## Tool Output:
# ["Let's catch up on the latest news from the stock market. From significant investments to major deals, quarterly earnings, fund raising and appointments, here’s a quick look at which stocks will be in focus in today's trade:\nResults Today\nTata Consultancy Services, Tata Elxsi, Indian Renewable Energy Development Agency, Anand Rathi Wealth, Den Networks, Arkade Developers, Ashoka Metcast, GM Breweries, Hathway Bhawani Cabletel, Infomedia Press, NB Footwear, and Reliance Naval and Engineering will release their quarterly earnings on October 10.\nQuarterly Earnings\nGTPL Hathway Q2 Consolidated (YoY)\nNet profit falls 61.7% to Rs 13.74 crore Vs Rs 35.9 crore\nRevenue increases 9.8% to Rs 855.6 crore Vs Rs 779.2 crore\nEBITDA declines 13.6% to Rs 107.4 crore Vs Rs 124.3 crore\nMargin drops to 12.55% Vs 16%\nStocks To Watch\nBritannia Industries\nThe company has announced a further strategic partnership with Bel Group for local cheese manufacturing in India. The factory at Ranjangaon, Maharashtra, will produce 10,000 tons of Britannia The Laughing Cow cheese products every year to meet the growing demands of Indian consumers. The joint venture will invest Rs 220 crore in the cheese plant.\nPNC Infratech\nThe company has emerged as the lowest bidder in an EPC project worth Rs 2,090.6 crore from the City & Industrial Development Corporation of Maharashtra (CIDCO). The project involves infrastructure development of 20-meter-wide roads, construction of various major and minor structures (flyovers, minor bridges, VUPS, PUPS, etc.), and allied electrical works (street lights) in TPS-8,\xa09, and TPS-12 under the NAINA project.\nRashtriya Chemicals and Fertilizers\nRCF has approved awarding an order worth Rs 1,000.3 crore to Larsen & Toubro for setting up a 1200 MTPD (DAP basis) complex fertilizer plant on an LSTK basis at RCF, Thal.\nSonata Software\nThe company has announced a strategic partnership with insurance technology provider iNube to enhance go-to-market efforts for insurers in the US and UK.\nJM Financial\nThe Competition Commission of India (CCI) has approved the Tranche 1 acquisition of 42.99% shareholding in JM Financial Credit Solutions (JMFCSL) by JM Financial for Rs 1,282 crore. Post acquisition of Tranche 1, JM Financial's shareholding in JMFCSL will increase from 46.68% to 89.67%. Additionally, the CCI has also approved the acquisition of 71.79% shareholding in JM Financial Asset Reconstruction Company (JMFARC) by JMFCSL from JM Financial for Rs 856 crore. Following the stake sale, JM Financial's shareholding in JMFARC will become nil, and JMFARC will cease to be a direct subsidiary of the company.\nIndian Railway Finance Corporation\nIRFC has appointed Manoj Kumar Dubey as an Additional Director to be designated as Chairman and Managing Director on the board of IRFC. He is also designated as CEO of the company for five years.\nAdani Enterprises\nThe company has opened its Qualified Institutions Placement (QIP) issue and set the floor price at Rs 3,117.475 per share. According to CNBC-TV18 sources, the QIP issue size may be Rs 4,200 crore.\nGR Infraprojects\nThe company has received a Letter of Acceptance for a project worth Rs 903.53 crore from the Maharashtra Metro Rail Corporation (Nagpur Metro Rail Project). The project involves the design and construction of an elevated metro viaduct.\nRain Industries\nCompany's subsidiary, Rain Carbon Inc, has signed an agreement with Northern Graphite Corporation to jointly develop and commercialize advanced battery anode material (BAM) used in lithium-ion batteries for electric vehicles.\nZee Entertainment Enterprises\nThe Independent Investigation Committee constituted by the Board of ZEE submitted its report to the Board. The Committee noted that the transactions under investigation did not adversely affect the company or its shareholders. The transactions were found to be part of the normal course of business, and no material irregularities were reported. The committee did ...
#
#
# You ONLY have access to the following tools, and should NEVER make up tools that are not listed here:
#
# Tool Name: market_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: market_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from news about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".          limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView news.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: retail_sentiment_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: retail_sentiment_analysis(stock_symbol: 'string', limit: 'integer') -      Perform sentiment analysis on posts from TradingView Minds about a stock symbol.          Args:         stock_symbol (str): The stock symbol to search for in tradingview ex: "HDFCBANK","LTIM","RELIANCE".         limit (int): Number of posts to fetch from TradingView.          Returns:         dict: Sentiment counts for TradingView posts.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'limit': {'title': 'Limit', 'type': 'integer'}}
# Tool Name: Search the internet(**kwargs: Any) -> Any
# Tool Description: Search the internet(search_query: 'string') - A tool that can be used to search the internet with a search_query. search_query: 'Mandatory search query you want to use to search the internet'
# Tool Arguments: {'search_query': {'description': 'Mandatory search query you want to use to search the internet', 'title': 'Search Query', 'type': 'string'}}
# Tool Name: yf_fundamental_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_fundamental_analysis(ticker: 'string') -      Perform a comprehensive fundamental analysis on the given stock symbol.          Args:         ticker (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".          Returns:         dict: A dictionary with the detailed fundamental analysis results.
# Tool Arguments: {'ticker': {'title': 'Ticker', 'type': 'string'}}
# Tool Name: yf_tech_analysis(*args: Any, **kwargs: Any) -> Any
# Tool Description: yf_tech_analysis(stock_symbol: 'string', period: 'string') -      Perform a comprehensive technical analysis on the given stock symbol.          Args:         stock_symbol (str): The stock ticker symbol of yfinance to analyze with suffix ".NS" , example: "RELIANCE.NS".         period (str): The time period for analysis. Default is "1y" (1 year).          Returns:         dict: A dictionary with the detailed technical analysis results.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'period': {'title': 'Period', 'type': 'string'}}
# Tool Name: tradingview_news_tool(*args: Any, **kwargs: Any) -> Any
# Tool Description: tradingview_news_tool(stock_symbol: 'string', max_articles: 'integer') -      Get the news articles from TradingView about a stock symbol.      Args:         stock_symbol (str): The stock symbol to search for, in tradingview example: "HDFCBANK","LTIM","RELIANCE".         max_articles (int): The maximum number of articles to fetch.      Returns:         list: A list containing the news articles from TradingView.
# Tool Arguments: {'stock_symbol': {'title': 'Stock Symbol', 'type': 'string'}, 'max_articles': {'title': 'Max Articles', 'type': 'integer'}}
#
# Use the following format:
#
# Thought: you should always think about what to do
# Action: the action to take, only one name of [market_sentiment_analysis, retail_sentiment_analysis, Search the internet, yf_fundamental_analysis, yf_tech_analysis, tradingview_news_tool], just the name, exactly as it's written.
# Action Input: the input to the action, just a simple python dictionary, enclosed in curly braces, using " to wrap keys and values.
# Observation: the result of the action
#
# Once all necessary information is gathered:
#
# Thought: I now know the final answer
# Final Answer: the final answer to the original input question
#
# VEDL
#
#
# # Agent: Chief Investment Strategist
# ## Thought: Thought: I have gathered fundamental analysis, technical analysis, and news articles related to Vedanta Limited. Now, I need to perform sentiment analysis on the news articles to gauge market and retail sentiment, and then synthesize all the information to form a comprehensive investment report.
# ## Using tool: market_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"limit\": 10}"
# ## Tool Output:
# {'hold': 9, 'sell': 1}
#
#
# # Agent: Chief Investment Strategist
# ## Using tool: retail_sentiment_analysis
# ## Tool Input:
# "{\"stock_symbol\": \"VEDL\", \"limit\": 10}"
# ## Tool Output:
# {'neutral': 7, 'negative': 1, 'positive': 2}
#
#
# # Agent: Chief Investment Strategist
# ## Final Answer:
# **Executive Summary:**
# Based on the fundamental analysis, Vedanta Limited exhibits a high P/E ratio, significant debt-to-equity ratio, negative revenue and net income growth, and a DCF valuation suggesting undervaluation. The technical analysis indicates a bullish trend, with potential resistance at 523.65 and support at 437. The sentiment analysis reveals a predominantly neutral sentiment from both market and retail perspectives, with a slight negative bias in retail sentiment.
#
# **Company Snapshot:**
# Vedanta Limited operates in the Basic Materials sector, specifically in the Other Industrial Metals & Mining industry. The company's key ratios reveal a P/E ratio of 35.14, indicating potential overvaluation or high growth expectations, and a high debt-to-equity ratio of 172.98, signifying significant leverage. The revenue growth (YoY) is negative at -2.48%, and the net income growth (YoY) is at -59.91%, indicating slowing growth and potential profitability issues. The company's DCF valuation stands at approximately 2.51 trillion, suggesting a current market undervaluation.
#
# **Financial Highlights:**
# The company's revenue growth (YoY) is negative at -2.48%, and the net income growth (YoY) is at -59.91%, indicating slowing growth and potential profitability issues. The company's DCF valuation stands at approximately 2.51 trillion, suggesting a current market undervaluation.
#
# **Technical Analysis:**
# The technical analysis indicates a bullish trend, with potential resistance at 523.65 and support at 437. The Moving Averages and Exponential MAs suggest a positive trend, while the MACD and Stochastic indicators show a neutral to bearish sentiment. The RSI is at 55.62, indicating a neutral stance.
#
# **Sentiment Analysis:**
# The sentiment analysis reveals a predominantly neutral sentiment from both market and retail perspectives, with a slight negative bias in retail sentiment. The market sentiment analysis shows 9 holds and 1 sell, while the retail sentiment analysis indicates 7 neutral, 1 negative, and 2 positive comments.
#
# **Investment Thesis:**
# The high P/E ratio and significant debt levels warrant caution, while the undervaluation indicated by the DCF valuation presents a potential opportunity. The bullish trend in technical analysis aligns with the positive sentiment from the market, despite the slight negative bias in retail sentiment. The slowing growth and profitability concerns highlighted in the fundamental analysis should be considered as potential risks.
#
# **Risk and Opportunity:**
# The major risk lies in the company's high debt-to-equity ratio and negative growth metrics, which may impact its financial stability and growth prospects. The opportunity lies in the undervaluation indicated by the DCF valuation and the bullish trend in the technical analysis, which may present a favorable entry point for investors.
#
# **Price Target:**
# Considering the undervaluation indicated by the DCF valuation and the bullish trend in the technical analysis, a 12-month price target of 550-570 is reasonable, with potential resistance at 523.65 and support at 437.
#
# In conclusion, while caution is advised due to the high P/E ratio and significant debt levels, the undervaluation and bullish trend present a compelling investment opportunity for Vedanta Limited.
#
#
# **Executive Summary:**
# Based on the fundamental analysis, Vedanta Limited exhibits a high P/E ratio, significant debt-to-equity ratio, negative revenue and net income growth, and a DCF valuation suggesting undervaluation. The technical analysis indicates a bullish trend, with potential resistance at 523.65 and support at 437. The sentiment analysis reveals a predominantly neutral sentiment from both market and retail perspectives, with a slight negative bias in retail sentiment.
#
# **Company Snapshot:**
# Vedanta Limited operates in the Basic Materials sector, specifically in the Other Industrial Metals & Mining industry. The company's key ratios reveal a P/E ratio of 35.14, indicating potential overvaluation or high growth expectations, and a high debt-to-equity ratio of 172.98, signifying significant leverage. The revenue growth (YoY) is negative at -2.48%, and the net income growth (YoY) is at -59.91%, indicating slowing growth and potential profitability issues. The company's DCF valuation stands at approximately 2.51 trillion, suggesting a current market undervaluation.
#
# **Financial Highlights:**
# The company's revenue growth (YoY) is negative at -2.48%, and the net income growth (YoY) is at -59.91%, indicating slowing growth and potential profitability issues. The company's DCF valuation stands at approximately 2.51 trillion, suggesting a current market undervaluation.
#
# **Technical Analysis:**
# The technical analysis indicates a bullish trend, with potential resistance at 523.65 and support at 437. The Moving Averages and Exponential MAs suggest a positive trend, while the MACD and Stochastic indicators show a neutral to bearish sentiment. The RSI is at 55.62, indicating a neutral stance.
#
# **Sentiment Analysis:**
# The sentiment analysis reveals a predominantly neutral sentiment from both market and retail perspectives, with a slight negative bias in retail sentiment. The market sentiment analysis shows 9 holds and 1 sell, while the retail sentiment analysis indicates 7 neutral, 1 negative, and 2 positive comments.
#
# **Investment Thesis:**
# The high P/E ratio and significant debt levels warrant caution, while the undervaluation indicated by the DCF valuation presents a potential opportunity. The bullish trend in technical analysis aligns with the positive sentiment from the market, despite the slight negative bias in retail sentiment. The slowing growth and profitability concerns highlighted in the fundamental analysis should be considered as potential risks.
#
# **Risk and Opportunity:**
# The major risk lies in the company's high debt-to-equity ratio and negative growth metrics, which may impact its financial stability and growth prospects. The opportunity lies in the undervaluation indicated by the DCF valuation and the bullish trend in the technical analysis, which may present a favorable entry point for investors.
#
# **Price Target:**
# Considering the undervaluation indicated by the DCF valuation and the bullish trend in the technical analysis, a 12-month price target of 550-570 is reasonable, with potential resistance at 523.65 and support at 437.
#
# In conclusion, while caution is advised due to the high P/E ratio and significant debt levels, the undervaluation and bullish trend present a compelling investment opportunity for Vedanta Limited.
